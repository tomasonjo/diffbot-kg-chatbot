# %%
data = {
   "version":3,
   "hits":1,
   "kgversion":"367",
   "request_ctx":{
      "query":{
         "type":"Person",
         "name":"Jensen Huang"
      },
      "query_ctx":{
         "search":"OFF"
      }
   },
   "data":[
      {
         "score":0.9295875060113099,
         "esscore":1735.7130126953125,
         "entity":{
            "twitterUri":"twitter.com/fakejensenhuang",
            "gender":{
               "normalizedValue":"Male"
            },
            "importance":97.1454086303711,
            "origin":"wikidata.org/entity/Q305177",
            "description":"Jensen Huang founded NVIDIA in 1993 and has served since its inception as president, chief executive officer and a member of the board of directors. Starting out in PC graphics, NVIDIA helped build the gaming market into the largest entertainment industry in the world today. Its invention of the GPU in 1999 made possible real-time programmable shading, which defines modern computer graphics, and later revolutionized parallel computing. More recently, GPU deep learning ignited modern AI - the next era of computing - with the GPU acting as the brain of computers, robots and self-driving cars that can perceive and understand the world. Huang is a recipient of the Dr. Morris Chang Exemplary Leadership Award from the Global Semiconductor Association in recognition of his exceptional contributions to driving the development, innovation, growth and long-term opportunities of the fabless semiconductor industry. He has received the Daniel J. Epstein Engineering Management Award from the University of Southern California, an honorary doctorate from Taiwanâ€™s National Chiao Tung University, and the EB Lemon Distinguished Alumni Award and an honorary doctorate from Oregon State University. He was named to the U.S. Immigrant Entrepreneur Hall of Fame when it was established in 2012. In 2017, Harvard Business Review ranked him No. 1 on its list of the worldâ€™s 100 best-performing CEOs, and, in 2016, No. 1 in the U.S., over the lifetime of their tenure. Prior to founding NVIDIA, Huang worked at LSI Logic and Advanced Micro Devices. He holds a BSEE degree from Oregon State University and an MSEE degree from Stanford University.",
            "educations":[
               {
                  "institution":{
                     "summary":"Private research university in Stanford, California, U.S.",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqw%3Exb%7D%5Bi%3Bl%2F%40qGksEgIXe%287KeD%29.5fx",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Stanford University",
                     "diffbotUri":"http://diffbot.com/entity/EYIgQu0uKMdqz5168f_zH4Q",
                     "targetDiffbotId":"EYIgQu0uKMdqz5168f_zH4Q",
                     "type":"Organization"
                  },
                  "isCurrent":"false",
                  "degree":{
                     "types":[
                        "Intangible",
                        "DegreeEntity"
                     ],
                     "name":"Master's (6 year program)",
                     "diffbotUri":"http://diffbot.com/entity/Ejdc_QVxaMi6uurL2kpLSnQ",
                     "targetDiffbotId":"Ejdc_QVxaMi6uurL2kpLSnQ",
                     "type":"DegreeEntity"
                  },
                  "from":{
                     "str":"d1990-XX-XX",
                     "precision":1,
                     "timestamp":631152000000
                  },
                  "to":{
                     "str":"d1992-XX-XX",
                     "precision":1,
                     "timestamp":694224000000
                  }
               },
               {
                  "institution":{
                     "summary":"Public research university in Corvallis, Oregon, United States",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Et%601Tr%3AYnU%5BL%5En%7Dt%40ckVx4X%3BBp1buDQ%40Z.Ar4",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Oregon State University",
                     "diffbotUri":"http://diffbot.com/entity/EVKTg6d-lMsWIC8NEgGrtyQ",
                     "targetDiffbotId":"EVKTg6d-lMsWIC8NEgGrtyQ",
                     "type":"Organization"
                  },
                  "isCurrent":"false",
                  "degree":{
                     "types":[
                        "Intangible",
                        "DegreeEntity"
                     ],
                     "name":"Bachelor's (4 year program)",
                     "diffbotUri":"http://diffbot.com/entity/EtWuqNi7UOGu2JRK_z95kDg",
                     "targetDiffbotId":"EtWuqNi7UOGu2JRK_z95kDg",
                     "type":"DegreeEntity"
                  },
                  "from":{
                     "str":"d1980-XX-XX",
                     "precision":1,
                     "timestamp":315532800000
                  },
                  "to":{
                     "str":"d1984-XX-XX",
                     "precision":1,
                     "timestamp":441763200000
                  }
               },
               {
                  "institution":{
                     "summary":"Public school in Aloha, Oregon, United States",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EOp%5C%5CmIjOTzR%2Fy_FYV6g%7E",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company"
                     ],
                     "name":"Aloha High School",
                     "diffbotUri":"http://diffbot.com/entity/E8bXEHoDTMo-7z3I3d9UrAQ",
                     "targetDiffbotId":"E8bXEHoDTMo-7z3I3d9UrAQ",
                     "type":"Organization"
                  },
                  "degree":{
                     "types":[
                        "Intangible",
                        "DegreeEntity"
                     ],
                     "name":"High School or Equivalent",
                     "diffbotUri":"http://diffbot.com/entity/Eo0L8FrRAM1aL2Fs7j4HHUw",
                     "targetDiffbotId":"Eo0L8FrRAM1aL2Fs7j4HHUw",
                     "type":"DegreeEntity"
                  }
               },
               {
                  "institution":{
                     "summary":"Institute based in Oneida, Kentucky",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSXzAoBWu.x0KwLZrUn.%5B%3CR0Aa4Hwygr9m6W%3Exl5G%60Bkxm%5Eg7%7B%40l3hza%7B.c%2F%3F",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company"
                     ],
                     "name":"Oneida Baptist Institute",
                     "diffbotUri":"http://diffbot.com/entity/EadBIhEwjMz-vk3zp4nGx5A",
                     "targetDiffbotId":"EadBIhEwjMz-vk3zp4nGx5A",
                     "type":"Organization"
                  }
               }
            ],
            "nationalities":[
               {
                  "name":"United States of America",
                  "type":"AdministrativeArea"
               },
               {
                  "name":"Taiwan",
                  "type":"AdministrativeArea"
               },
               {
                  "name":"Taiwanese, American",
                  "type":"AdministrativeArea"
               }
            ],
            "type":"Person",
            "allNames":[
               "Jensen Huang",
               "Huang",
               "Jen-Hsun Huang",
               "Ð”Ð¶ÐµÐ½ÑÐµÐ½ Ð¥ÑƒÐ°Ð½Ð³",
               "é»ƒä»å‹³",
               "Jensen",
               "Net Worth",
               "Jensen Huang Net Worth",
               "Jen-Hsun Huang Biography and Net Worth",
               "Mr. Huang",
               "Taiwanese, American  ðŸ’° Compare Jensen Huang",
               "Taiwanese, American ðŸ’° Compare Jensen Huang",
               "Ð”Ð¶ÐµÐ½ÑÑŠÐ½ Ð¥ÑƒÐ°Ð½Ð³",
               "à¦œà§‡à¦¨-à¦¸à§à¦¨ à¦¹à§à¦¯à¦¼à¦¾à¦‚",
               "Huang Zsen-hszÃ¼n",
               "ÔºÕ¥Õ¶ ÕÕ¸Ö‚Õ¶ Õ€Õ¸Ö‚Õ¡Õ¶",
               "Ð”Ð¶ÐµÐ½ÑÐµÐ½ Ð“ÑƒÐ°Ð½Ò‘",
               "NÌ‚g JÃ®n-hun",
               "ì  ìŠ¨ í™©",
               "Ø¬ÙŠÙ† Ø³ÙˆÙ† Ù‡ÙˆØ§Ù†Ø¬",
               "Ø¬ÙŠÙ†-Ø³ÙˆÙ† Ù‡ÙˆØ§Ù†Øº",
               "ã‚¸ã‚§ãƒ³ã‚¹ãƒ³ãƒ»ãƒ•ã‚¢ãƒ³",
               "Ø¬Ù† Ø³ÙˆÙ† Ù‡ÙˆØ§Ù†Ú¯",
               "Ø¬ÛŽÙ† Ø³ÙˆÙˆÙ† Ù‡ÙˆØ§Ù†Ú¯",
               "×’'× ×¡×Ÿ ×”×•×× ×’",
               "HoÃ ng NhÃ¢n HuÃ¢n",
               "í™©ëŸ°ì‰°",
               "í™©ì¸í›ˆ",
               "é»„ä»å‹²",
               "ã“ã† ã˜ã‚“ãã‚“",
               "Jen-Hsun \"Jensen\" Huang",
               "HuÃ¡ng RÃ©nxÅ«n",
               "Jen-Hsu Huang",
               "Mr. Jen-Hsun Huang"
            ],
            "skills":[
               {
                  "name":"sports",
                  "diffbotUri":"http://diffbot.com/entity/Eti7ViMwUOZmS7IEcT0Ptug",
                  "targetDiffbotId":"Eti7ViMwUOZmS7IEcT0Ptug"
               },
               {
                  "name":"table tennis",
                  "diffbotUri":"http://diffbot.com/entity/EIM9aHq89NgqcgX-XapXNSg",
                  "targetDiffbotId":"EIM9aHq89NgqcgX-XapXNSg"
               },
               {
                  "name":"teaching",
                  "diffbotUri":"http://diffbot.com/entity/Ez8ugmNmEN3mp_4eMLqGSsA",
                  "targetDiffbotId":"Ez8ugmNmEN3mp_4eMLqGSsA"
               },
               {
                  "name":"management",
                  "diffbotUri":"http://diffbot.com/entity/EpN3B3DbvMDyCVkan8GVUKQ",
                  "targetDiffbotId":"EpN3B3DbvMDyCVkan8GVUKQ"
               }
            ],
            "wikipediaPageviewsLastYearGrowth":2.575959,
            "birthPlace":{
               "country":{
                  "summary":"Country in East Asia",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvur%3EVM%40Nl%3C_4%40mMg1Ay%3CLvEs%3AVsPZqT9IO3SnB%5B%3DDjA%60%2F99%5Dp%3Ag%3C%7Cg.Ok%7B",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "Country"
                  ],
                  "name":"Taiwan",
                  "diffbotUri":"http://diffbot.com/entity/EP-lHngxXPDeoLGinsUr9Ew",
                  "targetDiffbotId":"EP-lHngxXPDeoLGinsUr9Ew",
                  "type":"Place"
               },
               "isCurrent":"false",
               "address":"Tainan, Taiwan",
               "city":{
                  "summary":"City in southern Taiwan",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDr%3EyO5%5Bd%3AY%5EJnQXVG%7C%3C_tQj9Xq%2Fhy_.Jf5",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "City"
                  ],
                  "name":"Tainan",
                  "diffbotUri":"http://diffbot.com/entity/E3Da2aeC7M-2Yq5i3vAilDA",
                  "targetDiffbotId":"E3Da2aeC7M-2Yq5i3vAilDA",
                  "type":"Place"
               },
               "latitude":23.10996437072754,
               "precision":14.180693626403809,
               "surfaceForm":"Tainan, Taiwan",
               "region":{
                  "summary":"City in southern Taiwan",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDr%3EyO5%5Bd%3AY%5EJnQXVG%7C%3C_tQj9Xq%2Fhy_.Jf5",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "City"
                  ],
                  "name":"Tainan",
                  "diffbotUri":"http://diffbot.com/entity/E3Da2aeC7M-2Yq5i3vAilDA",
                  "targetDiffbotId":"E3Da2aeC7M-2Yq5i3vAilDA",
                  "type":"Place"
               },
               "longitude":120.30115509033203
            },
            "origins":[
               "stocks-adviser.com/nvda/about/?mrjenhsunhuang",
               "mongodb.com/investors",
               "blogs.perficient.com/2018/03/20/ibm-think-journey-to-ai",
               "crunchbase.com/person/jen-hsun-huang",
               "zacks.com/stock/news/304723/The-Technology-Super-Cycle-5-Chip-Stocks-to-Buy-Now",
               "bigpanda.io/about-us",
               "es.marketscreener.com/cotizacion/accion/NVIDIA-CORPORATION-57355629/?jensenhuang",
               "bloomberg.com/profiles/people/1782546-huang-jensen",
               "pcmag.com/slideshow/story/335128/the-best-of-computex-2015",
               "forbes.com/profile/jensen-huang-1/?sh=5902b8073a6c",
               "en.wikipedia.org",
               "electronicproducts.com/Robotics/AI/AI_platform_for_robotics_systems_powers_autonomous_machines.aspx",
               "waatp.com/people/adam-mccuskey/874827",
               "piazza.com/about/investors",
               "forbes.com/profile/jensen-huang-1/?sh=250bbf713a6c",
               "bloomberg.com/profiles/people/1782546-jensen-huang",
               "en.wikipedia.org/wiki/Windows_RT",
               "insidertrades.com/nvidia-co-stock/mr-jen-hsun-huang",
               "bit-tech.net/news/tech/graphics/nvidia-geforce-grid/1",
               "nvidia.com/en-gb/about-nvidia/board-of-directors/jensen-huang",
               "marketscreener.com/business-leaders/JEN-HSUN-HUANG-3100/biography",
               "wikidata.org/entity/Q305177",
               "bloomberg.com/profile/person/1782546",
               "m.hardocp.com/news/2018/06/12/amd_graphics_inside_story?m=1",
               "investor.nvidia.com/governance/board-of-directors/default.aspx?jensenhuang",
               "nvidia.com/ko-kr/newsroom/bios/?jensenhuang",
               "cnbc.com/2018/06/13/cramer-introduces-new-high-quality-stock-group-the-100-billion-club.html",
               "globaldata.com/company-profile/nvidia-corp/?utm_source=cision&utm_medium=press-release&utm_campaign=gd_pr_influencer-nvidia&jenhsunhuang",
               "gamegpu.com/%D0%BE-%D0%BA%D0%BE%D0%BC%D0%BF%D0%B0%D0%BD%D0%B8%D0%B8-nvidia/o-kompanii-nvidiaÐ´Ð¶ÐµÐ½ÑÐµÐ½Ñ…ÑƒÐ°Ð½Ð³",
               "at.marketscreener.com/kurs/aktie/NVIDIA-CORPORATION-57355629/?jensenhuang",
               "en.wikipedia.org/wiki/Jensen_Huang",
               "m.hardocp.com/news/2018/03/22/late_night_hunt_showdown_streaming?m=1",
               "linkedin.com/in/jenhsunhuang",
               "celebritynetworth.com/richest-businessmen/richest-billionaires/jensen-huang-net-worth",
               "nvidianews.nvidia.com/bios/jensen-huang",
               "theorg.com/org/nvidia/team/jensen-huang",
               "linkedin.com/profile/view",
               "nvidianews.nvidia.com/multimedia/corporate/corporate-executives?jensenhuang",
               "tatlerasia.com/people/jensen-huang-zh-hant-en",
               "cvit.iiit.ac.in/news",
               "dbpedia.org/page/Jensen_Huang"
            ],
            "wikipediaPageviews":598457,
            "id":"Erp3EYknCP8q0-FX6HGkdqw",
            "crawlTimestamp":1714459624,
            "nbOrigins":41,
            "summary":"Taiwanese-American entrepreneur and businessman; founder and CEO of Nvidia",
            "image":"https://kg.diffbot.com/image/api/get?fetch=yes&urls=g%3Cj7guSXzAoBWu.x0KwLZrUn.%5B%3CR0Aa4Hwygr9m6W%3Exl5G%60BkxmY%3A%5C%3FRq%7BB%40Bh%3FX%28%3BxF%5DvIi%29.%7CS%60,g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FDvsr%3EoS%3A%60h%3AYcV%5BF%60n%28iI%5CvTj%2F%29.Miy,g%3Cj7P0St1N.6WyIn%7E.qNb%3D%60uHY%7C-7JxAbxVv4F-8ZrVh7V%3FVg%7C%5Dp9aKo3M2JbzWCtFy%3C%5B-%7Cz%7CRy.c2W",
            "types":[
               "Person"
            ],
            "images":[
               {
                  "url":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSXzAoBWu.x0KwLZrUn.%5B%3CR0Aa4Hwygr9m6W%3Exl5G%60BkxmY%3A%5C%3FRq%7BB%40Bh%3FX%28%3BxF%5DvIi%29.%7CS%60",
                  "primary":"true"
               },
               {
                  "url":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FDvsr%3EoS%3A%60h%3AYcV%5BF%60n%28iI%5CvTj%2F%29.Miy",
                  "primary":"false"
               },
               {
                  "url":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St1N.6WyIn%7E.qNb%3D%60uHY%7C-7JxAbxVv4F-8ZrVh7V%3FVg%7C%5Dp9aKo3M2JbzWCtFy%3C%5B-%7Cz%7CRy.c2W",
                  "primary":"false"
               },
               {
                  "url":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EN7%5Bn%3Fm6RiJjx3%60%7B%3E_%3E%60wBn%7EN4SnE%3B%7E%40Y.Vu4",
                  "primary":"false"
               }
            ],
            "wikipediaUri":"en.wikipedia.org/wiki/Jensen_Huang",
            "unions":[
               {
                  "person":{
                     "summary":"Co-founder of Jen-Hsun and Lori Huang Foundation, focusing on STEM education",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSasY.%3AXqGm%7CU1Dgq%5B%7BGQ8_.%7Dg6%5E-thf7tmsG%7CNIaQr8Q%2FPf%2F%5D%7ELK%3B%5Cr%3Bi%3APiGIu50%5C%7CgdSjw3W_o%3EWtBk.MlA",
                     "types":[
                        "Person"
                     ],
                     "name":"Lori Huang",
                     "diffbotUri":"http://diffbot.com/entity/E_lyELE9SNMOfcc78fMiing",
                     "targetDiffbotId":"E_lyELE9SNMOfcc78fMiing",
                     "type":"Person"
                  },
                  "type":"Marriage"
               }
            ],
            "diffbotUri":"http://diffbot.com/entity/Erp3EYknCP8q0-FX6HGkdqw",
            "nbIncomingEdges":0,
            "wikipediaPageviewsLastQuarter":1193718,
            "allUris":[
               "wikidata.org/entity/Q305177",
               "bloomberg.com/profile/person/1782546",
               "bloomberg.com/profiles/people/1782546-huang-jensen",
               "bloomberg.com/profiles/people/1782546-jensen-huang",
               "celebritynetworth.com/richest-businessmen/richest-billionaires/jensen-huang-net-worth",
               "crunchbase.com/person/jen-hsun-huang",
               "dbpedia.org/page/Jensen_Huang",
               "en.wikipedia.org",
               "en.wikipedia.org/wiki/Jensen_Huang",
               "linkedin.com/in/jenhsunhuang",
               "linkedin.com/profile/view",
               "theorg.com/org/nvidia/team/jensen-huang",
               "dbpedia.org/resource/Jensen_Huang",
               "twitter.com/fakejensenhuang",
               "g.co/kg/m/06n774"
            ],
            "employments":[
               {
                  "isCurrent":"true",
                  "employer":{
                     "summary":"American multinational technology company",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqr%3EsDe1L%5DY7PaG.2Nm",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Nvidia",
                     "diffbotUri":"http://diffbot.com/entity/E9nQaOvC9MXaUzXCuN81tFQ",
                     "targetDiffbotId":"E9nQaOvC9MXaUzXCuN81tFQ",
                     "type":"Organization"
                  },
                  "from":{
                     "str":"d1993-04-XX",
                     "precision":2,
                     "timestamp":733622400000
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Chief Officer",
                        "diffbotUri":"http://diffbot.com/entity/ETONJ_vUmODK7D7WTWa6OhA",
                        "targetDiffbotId":"ETONJ_vUmODK7D7WTWa6OhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Leadership",
                        "diffbotUri":"http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg",
                        "targetDiffbotId":"EVWkZnDeBNKaKUDZ_8WK0bg",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Founder",
                        "diffbotUri":"http://diffbot.com/entity/EoN4VH9EANdSbPUhVFBbVSQ",
                        "targetDiffbotId":"EoN4VH9EANdSbPUhVFBbVSQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"CEO",
                        "diffbotUri":"http://diffbot.com/entity/EsKRhWmcBM3q1_CQ_xGmtyA",
                        "targetDiffbotId":"EsKRhWmcBM3q1_CQ_xGmtyA",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"Founder & CEO"
               },
               {
                  "isCurrent":"true",
                  "employer":{
                     "summary":"Organization based in Watertown Town, Massachusetts",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EN7%5Bm%3Fl6TeGkx9c1%3FV2Sq%3EtGWaDpyEpRS.Pw4",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company"
                     ],
                     "name":"Harvard Business Review",
                     "diffbotUri":"http://diffbot.com/entity/EyDAB4ilkPeexb3lsQ9w2Hg",
                     "targetDiffbotId":"EyDAB4ilkPeexb3lsQ9w2Hg",
                     "type":"Organization"
                  },
                  "from":{
                     "str":"d2019-XX-XX",
                     "precision":1,
                     "timestamp":1546300800000
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"CEO",
                        "diffbotUri":"http://diffbot.com/entity/EsKRhWmcBM3q1_CQ_xGmtyA",
                        "targetDiffbotId":"EsKRhWmcBM3q1_CQ_xGmtyA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Leadership",
                        "diffbotUri":"http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg",
                        "targetDiffbotId":"EVWkZnDeBNKaKUDZ_8WK0bg",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Chief Officer",
                        "diffbotUri":"http://diffbot.com/entity/ETONJ_vUmODK7D7WTWa6OhA",
                        "targetDiffbotId":"ETONJ_vUmODK7D7WTWa6OhA",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"CEO"
               },
               {
                  "isCurrent":"true",
                  "employer":{
                     "summary":"American multinational technology company",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqr%3EsDe1L%5DY7PaG.2Nm",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Nvidia",
                     "diffbotUri":"http://diffbot.com/entity/E9nQaOvC9MXaUzXCuN81tFQ",
                     "targetDiffbotId":"E9nQaOvC9MXaUzXCuN81tFQ",
                     "type":"Organization"
                  },
                  "from":{
                     "str":"d1993-04-XX",
                     "precision":2,
                     "timestamp":733622400000
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Board Member",
                        "diffbotUri":"http://diffbot.com/entity/EnC5drWy1NVuOGQHd2ll0xw",
                        "targetDiffbotId":"EnC5drWy1NVuOGQHd2ll0xw",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"Board Member"
               },
               {
                  "isCurrent":"false",
                  "employer":{
                     "summary":"Semiconductors and software designer",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FbvAu%3EqAe-O%3Ba4D-thvG.Jcm",
                     "types":[
                        "Organization",
                        "OrganizationInvestor"
                     ],
                     "name":"LSI",
                     "diffbotUri":"http://diffbot.com/entity/EXRyVX5_IMGCbbM5m5W2r9A",
                     "targetDiffbotId":"EXRyVX5_IMGCbbM5m5W2r9A",
                     "type":"Organization"
                  },
                  "from":{
                     "str":"d1985-01-XX",
                     "precision":2,
                     "timestamp":473385600000
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Director",
                        "diffbotUri":"http://diffbot.com/entity/Eg3ddwx52PdewyUAwLb_Mmw",
                        "targetDiffbotId":"Eg3ddwx52PdewyUAwLb_Mmw",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "to":{
                     "str":"d1993-12-XX",
                     "precision":2,
                     "timestamp":754704000000
                  },
                  "title":"Director"
               },
               {
                  "isCurrent":"false",
                  "employer":{
                     "summary":"American multinational semiconductor company",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGQ%3Ef%3B%60LO%3Ba%3A.mN%60",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Advanced Micro Devices",
                     "diffbotUri":"http://diffbot.com/entity/EbFKs23aHO_qdYiWKisqivA",
                     "targetDiffbotId":"EbFKs23aHO_qdYiWKisqivA",
                     "type":"Organization"
                  },
                  "from":{
                     "str":"d1984-01-XX",
                     "precision":2,
                     "timestamp":441763200000
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Design and Graphic Arts",
                        "diffbotUri":"http://diffbot.com/entity/EnctjeggUO9y7jm4w6lcr_w",
                        "targetDiffbotId":"EnctjeggUO9y7jm4w6lcr_w",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "to":{
                     "str":"d1985-12-XX",
                     "precision":2,
                     "timestamp":502243200000
                  },
                  "title":"Microprocessor Designer"
               },
               {
                  "isCurrent":"true",
                  "employer":{
                     "summary":"American multinational technology company",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqr%3EsDe1L%5DY7PaG.2Nm",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Nvidia",
                     "diffbotUri":"http://diffbot.com/entity/E9nQaOvC9MXaUzXCuN81tFQ",
                     "targetDiffbotId":"E9nQaOvC9MXaUzXCuN81tFQ",
                     "type":"Organization"
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Chief Officer",
                        "diffbotUri":"http://diffbot.com/entity/ETONJ_vUmODK7D7WTWa6OhA",
                        "targetDiffbotId":"ETONJ_vUmODK7D7WTWa6OhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Leadership",
                        "diffbotUri":"http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg",
                        "targetDiffbotId":"EVWkZnDeBNKaKUDZ_8WK0bg",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Director",
                        "diffbotUri":"http://diffbot.com/entity/Eg3ddwx52PdewyUAwLb_Mmw",
                        "targetDiffbotId":"Eg3ddwx52PdewyUAwLb_Mmw",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Finance",
                        "diffbotUri":"http://diffbot.com/entity/EbaieGM3vPVO9gqXBLcHi7w",
                        "targetDiffbotId":"EbaieGM3vPVO9gqXBLcHi7w",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"CFO",
                        "diffbotUri":"http://diffbot.com/entity/EchjnRXI9M9CJnNp8eF088g",
                        "targetDiffbotId":"EchjnRXI9M9CJnNp8eF088g",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"Director of Finance/CFO"
               },
               {
                  "isCurrent":"true",
                  "employer":{
                     "summary":"Platform for pursuing innovative breakthroughs",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company"
                     ],
                     "name":"Nvidia GPU Ventures",
                     "diffbotUri":"http://diffbot.com/entity/EO8ZLuFTdO3aiyv3dU6bpaw",
                     "targetDiffbotId":"EO8ZLuFTdO3aiyv3dU6bpaw",
                     "type":"Organization"
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"CEO",
                        "diffbotUri":"http://diffbot.com/entity/EsKRhWmcBM3q1_CQ_xGmtyA",
                        "targetDiffbotId":"EsKRhWmcBM3q1_CQ_xGmtyA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Leadership",
                        "diffbotUri":"http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg",
                        "targetDiffbotId":"EVWkZnDeBNKaKUDZ_8WK0bg",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Founder",
                        "diffbotUri":"http://diffbot.com/entity/EoN4VH9EANdSbPUhVFBbVSQ",
                        "targetDiffbotId":"EoN4VH9EANdSbPUhVFBbVSQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"President",
                        "diffbotUri":"http://diffbot.com/entity/EoOGiQBKyPo6fxgo68SaLSw",
                        "targetDiffbotId":"EoOGiQBKyPo6fxgo68SaLSw",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Chief Officer",
                        "diffbotUri":"http://diffbot.com/entity/ETONJ_vUmODK7D7WTWa6OhA",
                        "targetDiffbotId":"ETONJ_vUmODK7D7WTWa6OhA",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"CEO, Founder & President"
               },
               {
                  "isCurrent":"false",
                  "employer":{
                     "summary":"AI and data science virtual accelerator",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EMs%3FWwHy4d8WcF%5CvG%60%3Deu",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"NVIDIA Inception",
                     "diffbotUri":"http://diffbot.com/entity/Es_h_vaeQPdOnECzAR8dHmg",
                     "targetDiffbotId":"Es_h_vaeQPdOnECzAR8dHmg",
                     "type":"Organization"
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"CEO",
                        "diffbotUri":"http://diffbot.com/entity/EsKRhWmcBM3q1_CQ_xGmtyA",
                        "targetDiffbotId":"EsKRhWmcBM3q1_CQ_xGmtyA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Leadership",
                        "diffbotUri":"http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg",
                        "targetDiffbotId":"EVWkZnDeBNKaKUDZ_8WK0bg",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Founder",
                        "diffbotUri":"http://diffbot.com/entity/EoN4VH9EANdSbPUhVFBbVSQ",
                        "targetDiffbotId":"EoN4VH9EANdSbPUhVFBbVSQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Chief Officer",
                        "diffbotUri":"http://diffbot.com/entity/ETONJ_vUmODK7D7WTWa6OhA",
                        "targetDiffbotId":"ETONJ_vUmODK7D7WTWa6OhA",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"Chief Executive Officer & Founder"
               },
               {
                  "employer":{
                     "summary":"American multinational technology company",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqr%3EsDe1L%5DY7PaG.2Nm",
                     "types":[
                        "Organization",
                        "Corporation",
                        "Company",
                        "OrganizationInvestor"
                     ],
                     "name":"Nvidia",
                     "diffbotUri":"http://diffbot.com/entity/E9nQaOvC9MXaUzXCuN81tFQ",
                     "targetDiffbotId":"E9nQaOvC9MXaUzXCuN81tFQ",
                     "type":"Organization"
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Shareholder",
                        "diffbotUri":"http://diffbot.com/entity/EnjEbsIYNORq7LaLzpGLaeg",
                        "targetDiffbotId":"EnjEbsIYNORq7LaLzpGLaeg",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"Owner"
               },
               {
                  "employer":{
                     "name":"Jen-Hsun and Lori Huang Living Trust",
                     "type":"Organization"
                  },
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Finance",
                        "diffbotUri":"http://diffbot.com/entity/EbaieGM3vPVO9gqXBLcHi7w",
                        "targetDiffbotId":"EbaieGM3vPVO9gqXBLcHi7w",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"TRUSTEE"
               },
               {
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Management",
                        "diffbotUri":"http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ",
                        "targetDiffbotId":"EpXGc9jmNPQW3wt-ny5SqCQ",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Leadership",
                        "diffbotUri":"http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg",
                        "targetDiffbotId":"EVWkZnDeBNKaKUDZ_8WK0bg",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Executive",
                        "diffbotUri":"http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA",
                        "targetDiffbotId":"EFHD6pfzYMtqdaaytNomkhA",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"President",
                        "diffbotUri":"http://diffbot.com/entity/EoOGiQBKyPo6fxgo68SaLSw",
                        "targetDiffbotId":"EoOGiQBKyPo6fxgo68SaLSw",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"president"
               },
               {
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Artificial Intelligence",
                        "diffbotUri":"http://diffbot.com/entity/ESsRhWRXQP4y38EZrrH8I6A",
                        "targetDiffbotId":"ESsRhWRXQP4y38EZrrH8I6A",
                        "type":"EmploymentCategory"
                     },
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Engineering, IT and Software Development",
                        "diffbotUri":"http://diffbot.com/entity/EphfPPRLfN4yo0a952UCnDA",
                        "targetDiffbotId":"EphfPPRLfN4yo0a952UCnDA",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"computer scientist"
               },
               {
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Engineering, IT and Software Development",
                        "diffbotUri":"http://diffbot.com/entity/EphfPPRLfN4yo0a952UCnDA",
                        "targetDiffbotId":"EphfPPRLfN4yo0a952UCnDA",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"engineer"
               },
               {
                  "categories":[
                     {
                        "types":[
                           "Intangible",
                           "EmploymentCategory"
                        ],
                        "name":"Politics",
                        "diffbotUri":"http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ",
                        "targetDiffbotId":"E1RVCb9E4Pmm4Ef66nDYygQ",
                        "type":"EmploymentCategory"
                     }
                  ],
                  "title":"business magnate"
               },
               {
                  "title":"entrepreneur"
               },
               {
                  "title":"businessperson"
               },
               {
                  "title":"tech VIP"
               }
            ],
            "birthDate":{
               "str":"d1963-02-17",
               "precision":3,
               "timestamp":-216864000000
            },
            "wikipediaPageviewsLastQuarterGrowth":1.8686455,
            "wikipediaPageviewsLastYear":2233830,
            "awards":[
               {
                  "date":{
                     "str":"d2021-XX-XX",
                     "precision":1,
                     "timestamp":1609459200000
                  },
                  "title":"Time 100"
               },
               {
                  "date":{
                     "str":"d2020-XX-XX",
                     "precision":1,
                     "timestamp":1577836800000
                  },
                  "title":"IEEE Founders Medal"
               }
            ],
            "crunchbaseUri":"crunchbase.com/person/jen-hsun-huang",
            "netWorth":{
               "currency":"USD",
               "value":72000000000.0
            },
            "name":"Jensen Huang",
            "allDescriptions":[
               "Jen-Hsun \"Jensen\" Huang (born 1963) is an American businessman, electrical engineer, and the co-founder, president and CEO of Nvidia. In March 2024, Forbes estimated Huang\\'s net worth at $81.7 billion, making him the 17th richest person in the world.",
               "Jensen Huang founded NVIDIA in 1993 and has served since its inception as president, chief executive officer and a member of the board of directors. Starting out in PC graphics, NVIDIA helped build the gaming market into the largest entertainment industry in the world today. Its invention of the GPU in 1999 made possible real-time programmable shading, which defines modern computer graphics, and later revolutionized parallel computing. More recently, GPU deep learning ignited modern AI - the next era of computing - with the GPU acting as the brain of computers, robots and self-driving cars that can perceive and understand the world. Huang is a recipient of the Dr. Morris Chang Exemplary Leadership Award from the Global Semiconductor Association in recognition of his exceptional contributions to driving the development, innovation, growth and long-term opportunities of the fabless semiconductor industry. He has received the Daniel J. Epstein Engineering Management Award from the University of Southern California, an honorary doctorate from Taiwanâ€™s National Chiao Tung University, and the EB Lemon Distinguished Alumni Award and an honorary doctorate from Oregon State University. He was named to the U.S. Immigrant Entrepreneur Hall of Fame when it was established in 2012. In 2017, Harvard Business Review ranked him No. 1 on its list of the worldâ€™s 100 best-performing CEOs, and, in 2016, No. 1 in the U.S., over the lifetime of their tenure. Prior to founding NVIDIA, Huang worked at LSI Logic and Advanced Micro Devices. He holds a BSEE degree from Oregon State University and an MSEE degree from Stanford University.",
               "Jen-Hsun Huang co-founded NVIDIA in 1993 and has since served as president, chief executive officer, and a member of the board of directors. Under his direction, NVIDIA has become the worldâ€™s leading visual-computing company and a key player in the fields of mobile and high-performance computing.  Mr. Huang held a variety of positions from 1985 to 1993 at LSI Logic Corp., a computer chip manufacturer, including leading the business unit responsible for the companyâ€™s system-on-a-chip strategy. He was a microprocessor designer from 1984 to 1985 at Advanced Micro Devices, Inc., a semiconductor company.  Mr. Huang holds a BSEE degree from Oregon State University and an MSEE degree from Stanford University.",
               "As of this writing, Jensen Huang owns 3.5% of Nvidia's total outstanding shares. He also owns an additional 3 million vested restricted stock units."
            ],
            "locations":[
               {
                  "country":{
                     "summary":"Country primarily located in North America",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "Country"
                     ],
                     "name":"United States of America",
                     "diffbotUri":"http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A",
                     "targetDiffbotId":"E01d4EK33MmCosgI2KXa4-A",
                     "type":"Place"
                  },
                  "isCurrent":"true",
                  "address":"Los Altos, California, USA",
                  "city":{
                     "summary":"City in Santa Clara County, California, United States",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvuT%3Eq%5D%3FLD8n%3ATY%3Dg3JgEPkCx4K0B%7Bs.%7BGW",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "City"
                     ],
                     "name":"Los Altos",
                     "diffbotUri":"http://diffbot.com/entity/ErEDetkttMdiVKBeEHwtsdQ",
                     "targetDiffbotId":"ErEDetkttMdiVKBeEHwtsdQ",
                     "type":"Place"
                  },
                  "metroArea":{
                     "summary":"Metropolitan area in California, United States",
                     "types":[
                        "Place",
                        "AdministrativeArea"
                     ],
                     "name":"San Francisco Bay Area",
                     "diffbotUri":"http://diffbot.com/entity/E9vk_v1rKPgitvjkH--IN8w",
                     "targetDiffbotId":"E9vk_v1rKPgitvjkH--IN8w",
                     "type":"Place"
                  },
                  "subregion":{
                     "summary":"County in California, United States",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40r%3ErO%3CLr2Y%5EBfA_%7EJt%40NeLn2L%7EL%60zdzEW%7DBf%3Cp%7EB%3FF%5C3%3Bgl%5E%7DT%7BF.7%5Bb",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "Subregion"
                     ],
                     "name":"Santa Clara County",
                     "diffbotUri":"http://diffbot.com/entity/E8Sjxl9YuMRCajUEPN2k9ew",
                     "targetDiffbotId":"E8Sjxl9YuMRCajUEPN2k9ew",
                     "type":"Place"
                  },
                  "latitude":37.376956939697266,
                  "precision":4.096416473388672,
                  "postalCode":"94040",
                  "surfaceForm":"Los Altos, California, USA",
                  "region":{
                     "summary":"State of the United States of America",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtr%3EnAo-8UY%5EBfA_%7EJt%40N%2CCS0ZsGZqQ%2F%3BO%3C%5EwBd2Uj9HvRq%3C%5E.Pw4",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "Region"
                     ],
                     "name":"California",
                     "diffbotUri":"http://diffbot.com/entity/El0_8ehooNxOPT36Y4RdV9w",
                     "targetDiffbotId":"El0_8ehooNxOPT36Y4RdV9w",
                     "type":"Place"
                  },
                  "longitude":-122.107421875
               },
               {
                  "country":{
                     "summary":"Country in East Asia",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvur%3EVM%40Nl%3C_4%40mMg1Ay%3CLvEs%3AVsPZqT9IO3SnB%5B%3DDjA%60%2F99%5Dp%3Ag%3C%7Cg.Ok%7B",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "Country"
                     ],
                     "name":"Taiwan",
                     "diffbotUri":"http://diffbot.com/entity/EP-lHngxXPDeoLGinsUr9Ew",
                     "targetDiffbotId":"EP-lHngxXPDeoLGinsUr9Ew",
                     "type":"Place"
                  },
                  "isCurrent":"false",
                  "address":"Tainan, Taiwan",
                  "city":{
                     "summary":"City in southern Taiwan",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDr%3EyO5%5Bd%3AY%5EJnQXVG%7C%3C_tQj9Xq%2Fhy_.Jf5",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "City"
                     ],
                     "name":"Tainan",
                     "diffbotUri":"http://diffbot.com/entity/E3Da2aeC7M-2Yq5i3vAilDA",
                     "targetDiffbotId":"E3Da2aeC7M-2Yq5i3vAilDA",
                     "type":"Place"
                  },
                  "latitude":23.10996437072754,
                  "precision":14.180693626403809,
                  "surfaceForm":"Tainan, Taiwan",
                  "region":{
                     "summary":"City in southern Taiwan",
                     "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDr%3EyO5%5Bd%3AY%5EJnQXVG%7C%3C_tQj9Xq%2Fhy_.Jf5",
                     "types":[
                        "Place",
                        "AdministrativeArea",
                        "City"
                     ],
                     "name":"Tainan",
                     "diffbotUri":"http://diffbot.com/entity/E3Da2aeC7M-2Yq5i3vAilDA",
                     "targetDiffbotId":"E3Da2aeC7M-2Yq5i3vAilDA",
                     "type":"Place"
                  },
                  "longitude":120.30115509033203
               }
            ],
            "location":{
               "country":{
                  "summary":"Country primarily located in North America",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "Country"
                  ],
                  "name":"United States of America",
                  "diffbotUri":"http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A",
                  "targetDiffbotId":"E01d4EK33MmCosgI2KXa4-A",
                  "type":"Place"
               },
               "isCurrent":"true",
               "address":"Los Altos, California, USA",
               "city":{
                  "summary":"City in Santa Clara County, California, United States",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvuT%3Eq%5D%3FLD8n%3ATY%3Dg3JgEPkCx4K0B%7Bs.%7BGW",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "City"
                  ],
                  "name":"Los Altos",
                  "diffbotUri":"http://diffbot.com/entity/ErEDetkttMdiVKBeEHwtsdQ",
                  "targetDiffbotId":"ErEDetkttMdiVKBeEHwtsdQ",
                  "type":"Place"
               },
               "metroArea":{
                  "summary":"Metropolitan area in California, United States",
                  "types":[
                     "Place",
                     "AdministrativeArea"
                  ],
                  "name":"San Francisco Bay Area",
                  "diffbotUri":"http://diffbot.com/entity/E9vk_v1rKPgitvjkH--IN8w",
                  "targetDiffbotId":"E9vk_v1rKPgitvjkH--IN8w",
                  "type":"Place"
               },
               "subregion":{
                  "summary":"County in California, United States",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40r%3ErO%3CLr2Y%5EBfA_%7EJt%40NeLn2L%7EL%60zdzEW%7DBf%3Cp%7EB%3FF%5C3%3Bgl%5E%7DT%7BF.7%5Bb",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "Subregion"
                  ],
                  "name":"Santa Clara County",
                  "diffbotUri":"http://diffbot.com/entity/E8Sjxl9YuMRCajUEPN2k9ew",
                  "targetDiffbotId":"E8Sjxl9YuMRCajUEPN2k9ew",
                  "type":"Place"
               },
               "latitude":37.376956939697266,
               "precision":4.096416473388672,
               "postalCode":"94040",
               "surfaceForm":"Los Altos, California, USA",
               "region":{
                  "summary":"State of the United States of America",
                  "image":"https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtr%3EnAo-8UY%5EBfA_%7EJt%40N%2CCS0ZsGZqQ%2F%3BO%3C%5EwBd2Uj9HvRq%3C%5E.Pw4",
                  "types":[
                     "Place",
                     "AdministrativeArea",
                     "Region"
                  ],
                  "name":"California",
                  "diffbotUri":"http://diffbot.com/entity/El0_8ehooNxOPT36Y4RdV9w",
                  "targetDiffbotId":"El0_8ehooNxOPT36Y4RdV9w",
                  "type":"Place"
               },
               "longitude":-122.107421875
            },
            "wikipediaPageviewsGrowth":0.29379043,
            "allOriginHashes":[
               "0Cl1tT0mOsWjj_SnOLWWFw",
               "OHtJFG4AO_S-eq32WSLhDQ",
               "GPLwo5CDMPurqACZgsKK8Q",
               "uAKHosAJPoW-X53Gvm4cCQ",
               "wb6semdZNmydSUknMXtOXw",
               "JNxNwDBhOEW1voVwHpqmuA",
               "9yk-PqEYNwWooBLMQIv6oA",
               "cCj0P0PHNP2WRvGsuApiWw",
               "0k3JeSn2MPm9bsyieGn7IQ",
               "TYBUWCHaNM6BNnhxjVhc7g",
               "RbogUxY2MLyOVy8oT6Hrgw",
               "vSwZKeK9NMi0-2zaqw71Lg",
               "iogRyteIP4q2wK3ze87mqQ",
               "0QY68YH-MG6V7ZPdW4ZxaQ",
               "DMmPuOfuOIyMr8tK7a5wGg",
               "LyUvgqt3N2urHx9kV1Wx1A",
               "KDeKNQTTORmrNgH160WDLw",
               "1qiNSwNbMR-Q-uT7nqbWng",
               "56mG2OY1NVu3d5VrrjkU1g",
               "VlxMF5mhP8Sj0IIFp-3-dA",
               "OcRiQPVxOv6pUGqla228eQ",
               "6xLiqHXnPuiv58zIqFAOuQ",
               "CyyQTxFyP8m50MX0GMPzMg",
               "ApW3T6-BN5We9TzszK5Wyg",
               "Xtwi3FFkOLah3cHRtiHcgg",
               "6SpZBFtKODmi-t5chEHasQ",
               "j5FE47z1NZG2GrEflsSXVA",
               "2Try24EtOtKExHigcN4lxw",
               "Xw_I93FxPOK2O2sukH8GKA",
               "vEtas3IuODG84M08iPfV6w",
               "USWc_9g5OcGb5OxpjqoAcw",
               "G9nQyqI6P0modaycohvE7A",
               "4VkyBjKIMfiUdjAjH_GkyA",
               "HhqEX_GQOv627KUQd0abuw",
               "WljsO_0xMy680i_Vec2ALg",
               "vv4qWIxjPuCD4m6nQ3UIvg",
               "MYAwyZUqM62opEXLhFwzuA",
               "idxRxBZXPl2s1OuJkKwa1g",
               "RZdKfVX2OBuMy9y6yXXoJg",
               "rp3EYknCP8q0-FX6HGkdqw",
               "vBwpuK-lMH-tuUbAsrFwxg"
            ],
            "linkedInUri":"linkedin.com/in/jenhsunhuang",
            "nameDetail":{
               "firstName":"Jensen",
               "lastName":"Huang"
            },
            "age":61
         },
         "errors":[
            
         ]
      }
   ],
   "errors":[
      
   ]
}

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['version', 'hits', 'kgversion', 'request_ctx', 'data', 'errors'])

# %%
import requests
from typing import Any, Dict
from urllib.parse import urlencode


DIFF_TOKEN = "d8f934b749507bc6a9939848e77b380c"


def process_entities(entity: str, type: str) -> Dict[str, Any]:
    """
    Fetch relevant articles from Diffbot KG endpoint
    """
    search_host = "https://kg.diffbot.com/kg/v3/enhance?"
    params = {"type": type, "name": entity, "token": DIFF_TOKEN}
    encoded_query = urlencode(params)
    url = f"{search_host}{encoded_query}"
    return requests.get(url).json()

# %%
data['data'][0]['entity']['netWorth']
# Out:
# {'currency': 'USD', 'value': 72000000000.0}

# %%
data['data'][0]['entity'].keys()
# Out:
# dict_keys(['twitterUri', 'gender', 'importance', 'origin', 'description', 'educations', 'nationalities', 'type', 'allNames', 'skills', 'wikipediaPageviewsLastYearGrowth', 'birthPlace', 'origins', 'wikipediaPageviews', 'id', 'crawlTimestamp', 'nbOrigins', 'summary', 'image', 'types', 'images', 'wikipediaUri', 'unions', 'diffbotUri', 'nbIncomingEdges', 'wikipediaPageviewsLastQuarter', 'allUris', 'employments', 'birthDate', 'wikipediaPageviewsLastQuarterGrowth', 'wikipediaPageviewsLastYear', 'awards', 'crunchbaseUri', 'netWorth', 'name', 'allDescriptions', 'locations', 'location', 'wikipediaPageviewsGrowth', 'allOriginHashes', 'linkedInUri', 'nameDetail', 'age'])

# %%
data['data'][0]['entity']['importance']
# Out:
# 97.1454086303711

# %%
data['data'][0]['entity']['origin']
# Out:
# 'wikidata.org/entity/Q305177'

# %%
data['data'][0]['entity']['nationalities']
# Out:
# [{'name': 'United States of America', 'type': 'AdministrativeArea'},
#  {'name': 'Taiwan', 'type': 'AdministrativeArea'},
#  {'name': 'Taiwanese, American', 'type': 'AdministrativeArea'}]

# %%
data['data'][0]['entity'].keys()
# Out:
# dict_keys(['twitterUri', 'gender', 'importance', 'origin', 'description', 'educations', 'nationalities', 'type', 'allNames', 'skills', 'wikipediaPageviewsLastYearGrowth', 'birthPlace', 'origins', 'wikipediaPageviews', 'id', 'crawlTimestamp', 'nbOrigins', 'summary', 'image', 'types', 'images', 'wikipediaUri', 'unions', 'diffbotUri', 'nbIncomingEdges', 'wikipediaPageviewsLastQuarter', 'allUris', 'employments', 'birthDate', 'wikipediaPageviewsLastQuarterGrowth', 'wikipediaPageviewsLastYear', 'awards', 'crunchbaseUri', 'netWorth', 'name', 'allDescriptions', 'locations', 'location', 'wikipediaPageviewsGrowth', 'allOriginHashes', 'linkedInUri', 'nameDetail', 'age'])

# %%
[{'series': el['series'],
 'amount': el.get('amount',{}).get('value'),
 'investors': [{'name': i['name'], 'type': i.get('type')} for i in el['investors']]}
               for el in data['data'][0]['entity']['investments']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 4
#       1 [{'series': el['series'],
#       2  'amount': el.get('amount',{}).get('value'),
#       3  'investors': [{'name': i['name'], 'type': i.get('type')} for i in el['investors']]}
# ----> 4                for el in data['data'][0]['entity']['investments']]
#
# KeyError: 'investments'

# %%
# Company
#Properties
type = row['type']
employees = row['nbEmployees'] # int
revenue = row['revenue']['value'] + row['revenue']['currency'] #string
yearly_revenues = row['yearlyRevenues']
stock = row['stock']
founding_date = row['foundingDate']
wikipedia = row['wikipediaUri']
ipo = row['ipo']
total_investment = row['totalInvestment']
linkedin = row['linkedInUri']
is_dissolved = row['isDissolved']
description = row['description']

# relationships
suppliers = row['suppliers']
competitors = row['competitors']
nace_classification = row['diffbotClassification']
founders = row['founders']
ceo = row['ceo']
investments = row['investments']
partnerships = row['partnerships']
board_members = row['boardMembers']
subsidiaries = row['subsidiaries']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 # Company
#       2 #Properties
# ----> 3 type = row['type']
#       4 employees = row['nbEmployees'] # int
#       5 revenue = row['revenue']['value'] + row['revenue']['currency'] #string
#
# NameError: name 'row' is not defined
