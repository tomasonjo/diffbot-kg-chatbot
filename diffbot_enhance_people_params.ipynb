# %%
data = {'version': 3,
 'hits': 1,
 'kgversion': '367',
 'request_ctx': {'query': {'type': 'Person', 'name': 'Barack Obama'},
  'query_ctx': {'search': 'OFF'}},
 'data': [{'score': 0.9849403098414954,
   'esscore': 2644.01904296875,
   'entity': {'twitterUri': 'twitter.com/BarackObama',
    'educations': [{'institution': {'summary': 'Law school',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EDr%3BU%7Bdv%3BK3M%5E4i0J%5EAT8',
       'types': ['Organization'],
       'name': 'University of Chicago',
       'diffbotUri': 'http://diffbot.com/entity/EYBlXiiBkO4-YZp-Rf4cwoA',
       'targetDiffbotId': 'EYBlXiiBkO4-YZp-Rf4cwoA',
       'type': 'Organization'},
      'isCurrent': False,
      'major': {},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': "Bachelor's (4 year program)",
       'diffbotUri': 'http://diffbot.com/entity/EtWuqNi7UOGu2JRK_z95kDg',
       'targetDiffbotId': 'EtWuqNi7UOGu2JRK_z95kDg',
       'type': 'DegreeEntity'},
      'from': {'str': 'd1997-XX-XX',
       'precision': 1,
       'timestamp': 852076800000},
      'to': {'str': 'd2002-XX-XX',
       'precision': 1,
       'timestamp': 1009843200000}},
     {'institution': {'summary': 'Law school of Harvard University in Cambridge, Massachusetts',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqt%3EmO%3Ecd%3E%5Ez%7D%5BOXb%3BnF%5CrC%5C%3AVvPZ4%5B.Jf5',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Harvard Law School',
       'diffbotUri': 'http://diffbot.com/entity/EZDlLECIDN_Gd3aerftYJBQ',
       'targetDiffbotId': 'EZDlLECIDN_Gd3aerftYJBQ',
       'type': 'Organization'},
      'isCurrent': False,
      'major': {},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': 'PhD or other Doctorate',
       'diffbotUri': 'http://diffbot.com/entity/ELnQKJ4qDPGicFk4Dp4r5og',
       'targetDiffbotId': 'ELnQKJ4qDPGicFk4Dp4r5og',
       'type': 'DegreeEntity'},
      'from': {'str': 'd1988-XX-XX',
       'precision': 1,
       'timestamp': 567993600000},
      'to': {'str': 'd1991-XX-XX', 'precision': 1, 'timestamp': 662688000000}},
     {'institution': {'summary': 'Private university in Cambridge, Massachusetts',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGn%3EmO%3Ecd%3E%5Ez6hAotJy%40a%2FCq%3AK1.l8W',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Harvard University',
       'diffbotUri': 'http://diffbot.com/entity/ENlaNjdfKOya3PKtV8LMilA',
       'targetDiffbotId': 'ENlaNjdfKOya3PKtV8LMilA',
       'type': 'Organization'},
      'isCurrent': False,
      'major': {},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': 'PhD or other Doctorate',
       'diffbotUri': 'http://diffbot.com/entity/ELnQKJ4qDPGicFk4Dp4r5og',
       'targetDiffbotId': 'ELnQKJ4qDPGicFk4Dp4r5og',
       'type': 'DegreeEntity'},
      'location': {'country': {'summary': 'Country primarily located in North America',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
        'types': ['Place', 'AdministrativeArea', 'Country'],
        'name': 'United States of America',
        'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
        'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
        'type': 'Place'},
       'address': 'Harvard, MA',
       'city': {'summary': 'Town in Worcester County, Massachusetts, United States',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvus%3EmO%3Ecd%3E%5Ez5iOgnpgCY%2CCM%7CV8DkvO%5Eh.8_l',
        'types': ['Place', 'AdministrativeArea', 'City'],
        'name': 'Harvard',
        'diffbotUri': 'http://diffbot.com/entity/Ej3rB7K8qN-6aw-eO2ubxhQ',
        'targetDiffbotId': 'Ej3rB7K8qN-6aw-eO2ubxhQ',
        'type': 'Place'},
       'metroArea': {'summary': 'Metropolitan area in Massachusetts, New Hampshire and Rhode Island, USA',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtp%3El%601Nw1l%7DPmLh%7DZ.G%5Bm',
        'types': ['Place', 'AdministrativeArea'],
        'name': 'Greater Boston',
        'diffbotUri': 'http://diffbot.com/entity/Es5VXYfClMLeSpzD5N0Cx1A',
        'targetDiffbotId': 'Es5VXYfClMLeSpzD5N0Cx1A',
        'type': 'Place'},
       'subregion': {'summary': 'County in Massachusetts, United States',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40o%3ErO%3CLr2YhBmKZr%40%7BJRzXxzL%7BJa%7EYx%3Fd7%5Dl%7DS%3CU_%3Fn5%3Fz82w%5BuA_.Xq%7B',
        'types': ['Place', 'AdministrativeArea', 'Subregion'],
        'name': 'Worcester County',
        'diffbotUri': 'http://diffbot.com/entity/E8u8vfcabMT6H3k7sglXmXw',
        'targetDiffbotId': 'E8u8vfcabMT6H3k7sglXmXw',
        'type': 'Place'},
       'latitude': 42.3587532043457,
       'precision': 165.21200561523438,
       'postalCode': '01752',
       'surfaceForm': 'Harvard, MA',
       'region': {'summary': 'State of the United States of America',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHp%3ExS%7DYb%3B%60z%7E%5BKlp%3BnL%60kXy%3E.5Y%60',
        'types': ['Place', 'AdministrativeArea', 'Region'],
        'name': 'Massachusetts',
        'diffbotUri': 'http://diffbot.com/entity/E0VAbhEeRNsSvhHIpmhd3Xw',
        'targetDiffbotId': 'E0VAbhEeRNsSvhHIpmhd3Xw',
        'type': 'Place'},
       'longitude': -71.53148651123047},
      'from': {'str': 'd1988-XX-XX',
       'precision': 1,
       'timestamp': 567993600000},
      'to': {'str': 'd1991-XX-XX', 'precision': 1, 'timestamp': 662688000000}},
     {'institution': {'summary': 'Private university in New York City',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stn8p.%5DjEp9G.Bd%7BkD7pNq9Lx-aZ%5Bw-Z%3C%5EO-D4Og-ayHQu%5Dw1s512zN_%3Cb4E.A%5Dm',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Columbia University',
       'diffbotUri': 'http://diffbot.com/entity/EwkfmjptIN4C7n6yx3oPRuA',
       'targetDiffbotId': 'EwkfmjptIN4C7n6yx3oPRuA',
       'type': 'Organization'},
      'isCurrent': False,
      'major': {},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': "Bachelor's (4 year program)",
       'diffbotUri': 'http://diffbot.com/entity/EtWuqNi7UOGu2JRK_z95kDg',
       'targetDiffbotId': 'EtWuqNi7UOGu2JRK_z95kDg',
       'type': 'DegreeEntity'},
      'from': {'str': 'd1981-XX-XX',
       'precision': 1,
       'timestamp': 347155200000},
      'to': {'str': 'd1983-XX-XX', 'precision': 1, 'timestamp': 410227200000}},
     {'institution': {'name': 'Columbia College', 'type': 'Organization'},
      'isCurrent': False,
      'location': {'country': {'summary': 'Country primarily located in North America',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
        'types': ['Place', 'AdministrativeArea', 'Country'],
        'name': 'United States of America',
        'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
        'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
        'type': 'Place'},
       'address': 'New york, NY',
       'city': {'summary': 'Most populous city in the United States',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FgvFT%3Ef%609%60b%3B%60z%2F_OXhGxBLIMyD.5Y%60',
        'types': ['Place', 'AdministrativeArea', 'City'],
        'name': 'New York City',
        'diffbotUri': 'http://diffbot.com/entity/EcMmgf99wMQ6XYnbChv5HiQ',
        'targetDiffbotId': 'EcMmgf99wMQ6XYnbChv5HiQ',
        'type': 'Place'},
       'metroArea': {'summary': 'Most populous metropolitan area in the United States',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGp%3EsG%7B%3Ah%40l%3AQiDb39t6%7ExIf.T0J',
        'types': ['Place', 'AdministrativeArea'],
        'name': 'New York metropolitan area',
        'diffbotUri': 'http://diffbot.com/entity/EAtK9ZhUYMKmI_UzSrYinmw',
        'targetDiffbotId': 'EAtK9ZhUYMKmI_UzSrYinmw',
        'type': 'Place'},
       'subregion': {'summary': 'County in New York, United States',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvun%3Es%5D%3Eak%7BQ4MfAZ%7CKhL_m%2CdbVwHg2_zEd%2CNf%3C%60%7C%2FkHbps%7BEPvJf%60O8%5EZ7%5D%3CE%5B%3EVz%2F_BDqAb1%3BpM%60wGkDQ2Kf4%5Bt%3Ch1w%3BV_cLdDn7BkniqX06%2Cw%40h4b0%3EcGW0Fi%2CHDRp6KzXcm-lUlLk1SxO.bF%5E',
        'types': ['Place', 'AdministrativeArea'],
        'name': 'Kings County',
        'diffbotUri': 'http://diffbot.com/entity/EKWYc_xx-NaabzSSg9oK5tw',
        'targetDiffbotId': 'EKWYc_xx-NaabzSSg9oK5tw',
        'type': 'Place'},
       'latitude': 40.68294906616211,
       'precision': 27.98809051513672,
       'postalCode': '11217',
       'surfaceForm': 'New york, NY',
       'region': {'summary': 'State of the United States of America',
        'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDp%3EsGo0d%3Cc%3FPfxZ%7DGx8Zg.o%3BK',
        'types': ['Place', 'AdministrativeArea', 'Region'],
        'name': 'New York',
        'diffbotUri': 'http://diffbot.com/entity/E1NxI_KXaMbiP5g2aM9MRdw',
        'targetDiffbotId': 'E1NxI_KXaMbiP5g2aM9MRdw',
        'type': 'Place'},
       'longitude': -73.9708023071289},
      'to': {'str': 'd1983-XX-XX', 'precision': 1, 'timestamp': 410227200000}},
     {'institution': {'summary': 'Liberal arts college in Los Angeles, California, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EN7%5Bs9m5LeFcx%2FdwHaDsg%3Eo%3DR%7D%5Dq%7EIuYX.Vu4',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Occidental College',
       'diffbotUri': 'http://diffbot.com/entity/Ecuy4mJIFMKq3NVzqeJEJiw',
       'targetDiffbotId': 'Ecuy4mJIFMKq3NVzqeJEJiw',
       'type': 'Organization'},
      'isCurrent': False,
      'major': {},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': "Bachelor's (4 year program)",
       'diffbotUri': 'http://diffbot.com/entity/EtWuqNi7UOGu2JRK_z95kDg',
       'targetDiffbotId': 'EtWuqNi7UOGu2JRK_z95kDg',
       'type': 'DegreeEntity'},
      'from': {'str': 'd1979-XX-XX',
       'precision': 1,
       'timestamp': 283996800000},
      'to': {'str': 'd1981-XX-XX', 'precision': 1, 'timestamp': 347155200000}},
     {'institution': {'summary': 'American oil company',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FdvCu%3EtQ%2FVg1h%3FBf-ItLxFYkYr-01Jh.c7%3E',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Occidental Petroleum',
       'diffbotUri': 'http://diffbot.com/entity/E4obtc1ZeNgaphjIUZ5I15g',
       'targetDiffbotId': 'E4obtc1ZeNgaphjIUZ5I15g',
       'type': 'Organization'},
      'isCurrent': False,
      'degree': {'name': 'Political Science', 'type': 'DegreeEntity'},
      'from': {'str': 'd1979-XX-XX',
       'precision': 1,
       'timestamp': 283996800000},
      'to': {'str': 'd1981-XX-XX', 'precision': 1, 'timestamp': 347155200000}},
     {'institution': {'summary': 'School located in Honolulu CDP, Hawaii',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stn8p.%5DjEp9G.Bd%7BknXnKneOz-ay_%2F-Z6Vn-j6RG-B%7EqqCZq0Od%7D%7EzN_%3Cb4E.A%5Dm',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Punahou School',
       'diffbotUri': 'http://diffbot.com/entity/EnJwt4Ue3P4WXR2Q3wc8X7Q',
       'targetDiffbotId': 'EnJwt4Ue3P4WXR2Q3wc8X7Q',
       'type': 'Organization'},
      'isCurrent': False,
      'from': {'str': 'd1971-XX-XX', 'precision': 1, 'timestamp': 31536000000},
      'to': {'str': 'd1979-XX-XX', 'precision': 1, 'timestamp': 283996800000}},
     {'institution': {'summary': 'State elementary school in Jakarta',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSXzAoBWu.x0KwLZrUn.%5B%3CR0Aa4Hwygr9m6W%3Exl5G%60Bkxm%5BDU%3BLr2YhJhAl3J%2F6%5ClCJ%2FYuDm%7B_%2F6Q%3CSdaq9WqL%60pIn8AmV%7C%2FR%7DHZ3Xrr%604%60u5q8F.Osz',
       'types': ['Organization', 'Company', 'Corporation'],
       'name': 'SDN Menteng 01',
       'diffbotUri': 'http://diffbot.com/entity/El1_LW2wcN7C-EhHf-9AZug',
       'targetDiffbotId': 'El1_LW2wcN7C-EhHf-9AZug',
       'type': 'Organization'},
      'isCurrent': False,
      'from': {'str': 'd1970-XX-XX', 'precision': 1, 'timestamp': 0},
      'to': {'str': 'd1971-XX-XX', 'precision': 1, 'timestamp': 31536000000}},
     {'institution': {'name': 'Noelani Elementary School',
       'type': 'Organization'},
      'isCurrent': False,
      'from': {'str': 'd1966-XX-XX',
       'precision': 1,
       'timestamp': -126230400000},
      'to': {'str': 'd1967-XX-XX', 'precision': 1, 'timestamp': -94694400000}},
     {'institution': {'summary': 'School in Burlington, Ontario, Canada',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stq5uGU%7B.5%3AQw.cs%60%3C%3CY1jh%2Ff%7EQYBv%3FV4Mm4b2MjIa%7DHuD4S5vY%3Ab%2Frni%3Acnw%40Eq%7EGt9UL%40ZAsWp%400%5B%2FtN1FACJMlr.rVn',
       'types': ['Organization'],
       'name': 'Nelson High School',
       'diffbotUri': 'http://diffbot.com/entity/ENU_IOnqdMlqaphWh9zzVQQ',
       'targetDiffbotId': 'ENU_IOnqdMlqaphWh9zzVQQ',
       'type': 'Organization'},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': 'High School or Equivalent',
       'diffbotUri': 'http://diffbot.com/entity/Eo0L8FrRAM1aL2Fs7j4HHUw',
       'targetDiffbotId': 'Eo0L8FrRAM1aL2Fs7j4HHUw',
       'type': 'DegreeEntity'}},
     {'institution': {'summary': 'High School in Chicago, Illinois, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FGvvt%3EpW%3ATb_i7M_%3F%5Enxx%3C%5De%28H3MuD%601%29.A%605',
       'types': ['Organization', 'Company', 'Corporation'],
       'name': 'King College Prep',
       'diffbotUri': 'http://diffbot.com/entity/EuEGXivI6PcKpUfq1XiuYWQ',
       'targetDiffbotId': 'EuEGXivI6PcKpUfq1XiuYWQ',
       'type': 'Organization'},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': 'High School or Equivalent',
       'diffbotUri': 'http://diffbot.com/entity/Eo0L8FrRAM1aL2Fs7j4HHUw',
       'targetDiffbotId': 'Eo0L8FrRAM1aL2Fs7j4HHUw',
       'type': 'DegreeEntity'}},
     {'institution': {'summary': 'High school in Colorado',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stq5uGU%7B.5%3AQw.cs%60%3C%3CY1jh%2Ff%7EQYBv%3FV4Mm4b2PiDf%2FoGirpMRD%3EfSx2%3BRCyM%5BryQ%3C%3Df%7C4L%3BVA%3F%3Da5T%2Fk%3D%5DNNM8.rIV',
       'types': ['Organization'],
       'name': 'Centaurus High School',
       'diffbotUri': 'http://diffbot.com/entity/EF6iXzD8fPg2yl0go39AtiA',
       'targetDiffbotId': 'EF6iXzD8fPg2yl0go39AtiA',
       'type': 'Organization'},
      'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': 'High School or Equivalent',
       'diffbotUri': 'http://diffbot.com/entity/Eo0L8FrRAM1aL2Fs7j4HHUw',
       'targetDiffbotId': 'Eo0L8FrRAM1aL2Fs7j4HHUw',
       'type': 'DegreeEntity'}},
     {'degree': {'types': ['Intangible', 'DegreeEntity'],
       'name': "Bachelor's (4 year program)",
       'diffbotUri': 'http://diffbot.com/entity/EtWuqNi7UOGu2JRK_z95kDg',
       'targetDiffbotId': 'EtWuqNi7UOGu2JRK_z95kDg',
       'type': 'DegreeEntity'}},
     {'institution': {'name': 'Many Schools', 'type': 'Organization'}}],
    'nationalities': [{'name': 'United States of America',
      'type': 'AdministrativeArea'},
     {'name': 'Kenya', 'type': 'AdministrativeArea'},
     {'name': 'United States of America', 'type': 'AdministrativeArea'}],
    'type': 'Person',
    'allNames': ['Barack Obama',
     'Barack Hussein Obama II',
     'Barack H Obama',
     'barack obama',
     'Barrack Obama',
     'باراک حسين اوباما',
     'ბარაქ ობამა',
     'Барақ Обама',
     'بارک اوبامہ',
     'Barak Obama',
     'ባራክ ኦባማ',
     'باراك أوباما',
     "বাৰাক অ'বামা",
     'Барак Обама',
     'byRAK.obamas',
     'Обама, Барак',
     'Барак Абама',
     '巴拉克·奧巴馬',
     'Обамань Барак',
     'বারাক ওবামা',
     '贝拉克·奥巴马',
     'ཨོ་བྷ་མ།',
     'बराक ओबामा',
     'بارڪ اوباما',
     'ܒܪܐܩ ܐܘܒܐܡܐ',
     'බැරැක් ඔබාමා',
     'باراک اوباما',
     'باراك اوباما',
     'பராக் ஒபாமா',
     'బరాక్ ఒబామా',
     'Баракъ Обама',
     'Барак Ҳусейн Обама',
     'บารัก โอบามา',
     '바라크 오바마',
     'Baraq Husseyın Obama II',
     'Обама',
     'Barack Hussein Obama',
     'ބަރަކް އޮބާމާ',
     'باراك ئوباما',
     '奧巴馬',
     'بارک اوباما',
     'Baraks Obama',
     'Μπαράκ Ομπάμα',
     'ᏆᎳᎩ ᎣᏆᎹ',
     'Barak Ubama',
     'ⴱⴰⵔⴰⴽ ⵓⴱⴰⵎⴰ',
     'બરાક ઓબામા',
     'باراک ئۆباما',
     'ברק אובמה',
     'ߓߙߊߞ ߏߓߡߊ߫',
     'באראק אבאמא',
     'Բարաք Օբամա',
     'Aubahmaj',
     'ᐸᕌᒃ ᐅᐹᒪ',
     'バラク・オバマ',
     'बाराक ओबामा',
     'ბარაკ ობამა',
     '巴拉克·奥巴马',
     'បារ៉ាក់ អូបាម៉ា',
     'ಬರಾಕ್ ಒಬಾಮ',
     '버락 오바마',
     '巴拉克·歐巴馬',
     'بَراک اؤبامہ',
     'Барак Хусеин Обама',
     'Baracus Obama',
     'ບາຣັກ ໂອບາມາ',
     'Պարաք Օպամա',
     'ബറാക്ക് ഒബാമ',
     'Obama Barak',
     'ဘာရက် အိုဘားမား',
     'Hastiin alą́ąjįʼ dahsidáhígíí Barack Obama',
     'ବରାକ ଓବାମା',
     'ᱵᱟᱨᱟᱠ ᱚᱵᱟᱢᱟ',
     'ਬਰਾਕ ਓਬਾਮਾ',
     'बराक हुसैन ओबामा द्वितीय',
     'बराक ओबामा द्वितीय',
     'बराक हुसैन ओबामा',
     'ओबामा',
     'Obama',
     'ߓߙߊߞ ߤߎߛߊߦߣ ߏߓߡߊ߫ ߂߲',
     'ߓߙߊߞ ߏߓߡߊ߫ ߂߲',
     'ߓߙߊߞ ߤߎߛߊߦߣ ߏߓߡߊ߫',
     'ߏߓߡߊ߫',
     'ߞߊ߲ߕߌ߮ ߏߓߡߊ߫',
     'Barack Obama II',
     'Honorable Barack Obama',
     '歐巴馬',
     '巴拉克·欧巴马',
     '貝拉克·奧巴馬',
     '贝拉克·侯赛因·奥巴马',
     '贝拉克·侯赛因·奥巴马二世',
     '巴拉克·海珊·歐巴馬二世',
     '歐巴馬總統',
     '奧巴馬總統',
     '奥巴马',
     'باراك حسين أوباما',
     'باراك حسين أوباما الثاني',
     'أوباما',
     'باري أوباما',
     'اوباما',
     'اباما',
     'أباما',
     'بارک حسين اوباما II',
     'バラック・オバマ',
     'バラク・フセイン・オバマ',
     'バラク・オバマ・フセイン・ジュニア',
     'Barack Hussein Obama, Jr.',
     'Barack H. Obama',
     'Barack Hussein Obama al II-lea',
     'Барак Хуссейн Обама II',
     'Барак Хуссейн Обама-младший',
     'Бара́к Хуссе́йн Оба́ма',
     'Барак Хусейн Абама II',
     'Барак Хюсеин Обама',
     'ბარაკ ჰუსეინ ობამა II',
     'ბარაკ ობამა II',
     'Barack Husein Obama',
     'Барак Хусејин Обама II',
     'Барак Обама II',
     'Барак Хусејн Обама',
     'Бари Обама',
     'председник Обама',
     'председник Барак Обама',
     'БХО',
     'Барак',
     'Barack',
     '버락 후세인 오바마',
     'Rais Obama',
     'பாரக் ஒபாமா',
     'பராக் உசேன் ஒபாமா',
     'ஒபாமா',
     'ఒబామా',
     'Baracus Husseinus Obama minor',
     '바라크 후쎄인 오바마',
     'Абама',
     'Präsident Obama',
     'Präsident Barack Obama',
     'US-Präsident Obama',
     'US-Präsident Barack Obama',
     'Barry Obama',
     'President Obama',
     'BHO',
     'Б.Обама',
     'Μπάρακ Ομπάμα',
     'Ομπάμα',
     'President Barack Obama',
     'ᏆᎳᎩ ᎱᏎᎢᏂ ᎣᏆᎹ ᎣᏂᎡᎯ',
     'Barack Hussein Obama Jr.',
     'Barack Hussein Obama Jr',
     'Barack Hussein Obama, Jr',
     'Barack Obama Jr',
     'Barack Obama, Jr.',
     'Barack Obama Jr.',
     'Barack Obama, Jr',
     'Barack Obama Junior',
     'باراک حسین اوباما',
     'ברק אובאמה',
     'pages',
     'theoriginaljaybird',
     'potus44',
     'POTUS44'],
    'skills': [{'name': 'teaching',
      'diffbotUri': 'http://diffbot.com/entity/Ez8ugmNmEN3mp_4eMLqGSsA',
      'targetDiffbotId': 'Ez8ugmNmEN3mp_4eMLqGSsA'},
     {'name': 'law',
      'diffbotUri': 'http://diffbot.com/entity/EqlWF_NiBOwmSYpcgmZLFtw',
      'targetDiffbotId': 'EqlWF_NiBOwmSYpcgmZLFtw'},
     {'name': 'constitutional law',
      'diffbotUri': 'http://diffbot.com/entity/EkWFWgMKVNk67qz9U5jIFtQ',
      'targetDiffbotId': 'EkWFWgMKVNk67qz9U5jIFtQ'},
     {'name': 'civil rights',
      'diffbotUri': 'http://diffbot.com/entity/EO1Fy9v7iNbuyR5plfqJPdQ',
      'targetDiffbotId': 'EO1Fy9v7iNbuyR5plfqJPdQ'}],
    'emailAddresses': [{'contactString': 'barack.obama@gmail.com',
      'type': 'None'}],
    'youtubeUri': 'youtube.com/channel/UCdn86UYrf54lXfVli9CB6Aw',
    'children': [{'summary': 'Daughter of former US President Barack Obama and Michelle Obama',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stx.o8MkA-xMoYd%7C.pBYITn%7B_%7ERwsvZ%7C9gD%7EM%7Bfv%7B%5BP%3AC3%7EX%5EX%5DozK%3Bdne%5B%2FKZ%3AMyyi%3BghGD%3DEu4oo_8gN%3BgotiENJROJln%3Ej%5EIh%3BHw%5CijTG%3E_.%5D2%7Er.tKX',
      'types': ['Person'],
      'name': 'Sasha Obama',
      'diffbotUri': 'http://diffbot.com/entity/EL9Ix0cQTOxSrcqC8-zKYbQ',
      'targetDiffbotId': 'EL9Ix0cQTOxSrcqC8-zKYbQ',
      'type': 'Person'},
     {'summary': 'Daughter of former US President Barack Obama and Michelle Obama',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St1N.6WyIn%7E.qNb%3D%60uHY%7C-5JxAcxVv4F-8ZrVh7V%3FVg%7C%5Dp9aKo3M1Ja%7EWf%7E.pGT',
      'types': ['Person'],
      'name': 'Malia Obama',
      'diffbotUri': 'http://diffbot.com/entity/EY2at4AtINry3DcMSENOrNg',
      'targetDiffbotId': 'EY2at4AtINry3DcMSENOrNg',
      'type': 'Person'}],
    'id': 'E0Akwc0aKMKmTclQRNAiwRQ',
    'politicalAffiliation': [{'name': 'Democratic Party',
      'type': 'Organization'}],
    'nbOrigins': 40,
    'height': 1.85,
    'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&urls=g%3Cj7guSXzAoBWu.x0KwLZrUn.%5B%3CR0Aa4Hwygr9m6W%3Exl5G%60Bkxm_GS%3FVg1h%3F%40%3C9kp%3Bq6%3ChEr%7C.%7CS%60,g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHR%3Eu%601%60l0_9UYjZ19iBLUFf8E.Miy,g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EN7%5Bs%3Ef%3CTiKkxzU%7EWg%3Dfx%3Dq6W%2FKaE_%7EGV.Vu4',
    'images': [{'url': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSXzAoBWu.x0KwLZrUn.%5B%3CR0Aa4Hwygr9m6W%3Exl5G%60Bkxm_GS%3FVg1h%3F%40%3C9kp%3Bq6%3ChEr%7C.%7CS%60',
      'primary': True},
     {'url': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHR%3Eu%601%60l0_9UYjZ19iBLUFf8E.Miy',
      'primary': False},
     {'url': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EN7%5Bs%3Ef%3CTiKkxzU%7EWg%3Dfx%3Dq6W%2FKaE_%7EGV.Vu4',
      'primary': False},
     {'url': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSasW.%3AXqGm%7CU1Dgq%5B%7BGQ8_.%7Dg6%5E-gm%3E%7DJCCMDDZaQr8Q%2FPf%2F%5D%7ELK%3B%5Cr%3Bi%3APiGj25%7EGS5%5E3%7E05hBo%3EWtBk.MlA',
      'primary': False},
     {'url': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7guSasW.%3AXqGm%7CU1Dgq%5B%7BGQ8_.%7Dg6%5E-V%2F%609%7C%2FtK1lraQr8Q%2FPf%2F%5D%7ELK%3B%5Cr%3Bi%3APiGjF5jkdO%60ysV%5B-ho%3EWtBk.MlA',
      'primary': False},
     {'url': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St1N.6WyIn%7E.qNb%3D%60uHY%7C-7JxAbxVv4F-8ZrVh7V%3FVg%7C%5Dp9aKo3L3Jb%7BW%3BpJg%3AX-3g%7CQs-z.Z1%3E',
      'primary': False}],
    'wikipediaUri': 'en.wikipedia.org/wiki/Barack_Obama',
    'diffbotUri': 'http://diffbot.com/entity/E0Akwc0aKMKmTclQRNAiwRQ',
    'nbIncomingEdges': 70,
    'weight': 80,
    'wikipediaPageviewsLastQuarterGrowth': 0.027950196,
    'wikipediaPageviewsLastYear': 11065894,
    'name': 'Barack Obama',
    'nbFollowers': 133899684,
    'allOriginHashes': ['towL4v6TNXagfFa6R57-HQ',
     '2wIZ6U9FOCupkA7QTTriNw',
     'UodFkyN3Nf6Olz6uAUIxJQ',
     'YxwlI6o0PUOID0ZDayLfVg',
     'fPhpw3G5MNG3Dei7pBqbRQ',
     'a2hJL5hcOfOSwaxF4tkpew',
     'X6pmjkyzMlWuOAuoHjUakg',
     'kJPrHQKuPwSttNz93Fo8fA',
     'BtUCmOl-PV-uQvNU0jnZww',
     'CnGOUTJdPAOJNWkykp311A',
     'Jf1D4UTeNHK-yqBguA61MQ',
     'R-Y4DlBDMPOd5wE3xBulRw',
     'F8z5hTEWNqK5lB5juH3Ibg',
     'vk5Z1tQMPx2h9jVFGVeeAQ',
     'ki88k-pHP8SLzmdny5UVSg',
     'xpYhvotzMcm0-U6cpFtktg',
     'eHAfYxnUN_mAOd1Y4YuxRw',
     'Ih6LGntNOeOd-vBovaEcMQ',
     '0QY68YH-MG6V7ZPdW4ZxaQ',
     'hfFE9GiaPSm5a8xBCUqY4A',
     'FmNtXHDVOA-owIQAigxvvw',
     '41JWz9aVP8qQIHniDqR8MA',
     'LSMGTkVsPQOvAPg17o36jA',
     'P1pj1i9wM0uMt53i5GBqDA',
     'VeAdMsgYPI-dJ8HZemE2kg',
     'BPABZ4PZOZmy-p2mkGdIyg',
     'hiMUo781PK-Ry2LG0qO4Gg',
     'RxoQBqCSPm2RORmAGFAUdw',
     'ycNhgfhtM7-jPYpBi84E2g',
     'G0rGBjEEPk-Dibg1wpniBw',
     'L4cbfuYtMxqTR6cDMfkeww',
     'mo1nop_XPBeNfsocFFlEfQ',
     'SeQQt8KNN-mUBywNQheNFQ',
     'gYPh1UQSNPKqndHPs23N2A',
     'ynSWOogkOjeZVLFKRehSVQ',
     'r-zOnUnEPEWGSz02amodPg',
     '01d4EK33MmCosgI2KXa4-A',
     'y4uVCiAEPc-In6WEuKvktQ',
     '0Akwc0aKMKmTclQRNAiwRQ',
     'CgRLziF_NbOtckWsNnEvLA'],
    'linkedInUri': 'linkedin.com/in/barackobama',
    'nameDetail': {'firstName': 'Barack',
     'lastName': 'Obama',
     'middleName': ['Hussein']},
    'parents': [{'summary': 'American anthropologist, mother of Barack Obama',
      'types': ['Person'],
      'name': 'Ann Dunham',
      'diffbotUri': 'http://diffbot.com/entity/E4VtmioahPd2gAsMDE3sK4A',
      'targetDiffbotId': 'E4VtmioahPd2gAsMDE3sK4A',
      'type': 'Person'},
     {'summary': 'Economist, father of Barack Obama jr.',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stx.o8MkA-xMoYd%7C.pBYITn%7B_%7ERwsvZ%7C9g9%5B%7B5sL%5DbDd33%2F27mPozK%7EQ1s%5B%2FKO%3AZ9yh%7B%5B%5CR%3C%5BBu7gqTeIR%3BgotiENJROJln%3Ej%5EI%7EG%3Bv%5C3rVtK_.%5D2%7Er.tKX',
      'types': ['Person'],
      'name': 'Barack Obama Sr.',
      'diffbotUri': 'http://diffbot.com/entity/EXWBQJBtvMsG79aPy1g99-Q',
      'targetDiffbotId': 'EXWBQJBtvMsG79aPy1g99-Q',
      'type': 'Person'}],
    'gender': {'normalizedValue': 'Male'},
    'importance': 97.59281158447266,
    'origin': 'wikidata.org/entity/Q76',
    'description': 'Barack Hussein Obama II (born August 4, 1961) is an American politician who served as the 44th president of the United States from 2009 to 2017. A member of the Democratic Party, he was the first in U.S. history. Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, as an Illinois state senator from 1997 to 2004, and as a community service organizer, civil rights lawyer, and university lecturer.',
    'homepageUri': 'barackobama.com',
    'wikipediaPageviewsLastYearGrowth': 0.060099173,
    'birthPlace': {'country': {'summary': 'Country primarily located in North America',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
      'types': ['Place', 'AdministrativeArea', 'Country'],
      'name': 'United States of America',
      'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
      'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
      'type': 'Place'},
     'address': 'Hawaii',
     'latitude': 19.647634506225586,
     'precision': 168.5026092529297,
     'surfaceForm': 'Hawaii',
     'region': {'summary': 'State of the United States of America',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FDvsO%3ExS%7DYb%3B%60zUb%3DXbLgKReSkz%7CsZZ%7BY.Jf5',
      'types': ['Place', 'AdministrativeArea', 'Region'],
      'name': 'Hawaii',
      'diffbotUri': 'http://diffbot.com/entity/E8C57xBfCOsyYwfJ2yuuJEA',
      'targetDiffbotId': 'E8C57xBfCOsyYwfJ2yuuJEA',
      'type': 'Place'},
     'longitude': -155.5332489013672},
    'origins': ['classmates.com/people/barrack-obama/8725928770',
     'wikidata.org/entity/Q55539',
     'facebook.com/POTUS44',
     'facebook.com/theoriginaljaybird',
     'classmates.com/people/Barack-Obama/8700666384',
     'plus.google.com/103577439188064636391',
     'crunchbase.com/person/barack-obama',
     'wikidata.org/entity/Q117480686',
     'classmates.com/people/barack-obama/8724207129',
     'classmates.com/people/Barack-Obama/8704255405',
     'classmates.com/people/barack-obama/8725018180',
     'classmates.com/people/barack-obama/8741335960',
     'facebook.com/pages/category/Public-Figure/POTUS44',
     'en.wikipedia.org/wiki/Barack_Obama',
     'en.wikipedia.org',
     'wikidata.org/entity/Q76',
     'bloomberg.com/profile/person/3296948',
     'dbpedia.org/page/Barack_Obama',
     'plus.google.com/107385984930630263523',
     'wikidata.org/entity/Q30',
     'classmates.com/people/Barack-Obama/8724207129',
     'classmates.com/people/barack-obama/8704255405',
     'linkedin.com/in/barackobama',
     'wikidata.org/entity/Q20086735',
     'wikidata.org/entity/Q808796',
     'wikidata.org/entity/Q21193',
     'facebook.com/pages/category/Artist/theoriginaljaybird',
     'classmates.com/people/barack-obama/8704402335',
     'lytrondesign.com/brand-archetypes/ruler-brand-archetype/?barackobama',
     'classmates.com/people/barack-obama/10100943046',
     'plus.google.com/112746106941558590272',
     'classmates.com/people/Barack-Obama/8704402335',
     'classmates.com/people/barack-obama/8700666384',
     'classmates.com/people/Barrack-Obama/8725928770',
     'facebook.com/potus44',
     'theorg.com/org/obama-for-america/team/barack-obama',
     'celebritynetworth.com/richest-politicians/presidents/barack-obama-net-worth',
     'classmates.com/people/Barack-Obama/8725018180',
     'pl.pinterest.com/pin/71424344069811059',
     'linkedin.com/in/barack-obama-8367661a8'],
    'wikipediaPageviews': 919234,
    'crawlTimestamp': 1714459624,
    'facebookUri': 'facebook.com/barackobama',
    'summary': 'President of the United States from 2009 to 2017',
    'types': ['Person', 'PersonInvestor'],
    'unions': [{'person': {'summary': 'Lawyer and former First Lady of the United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FfvEq%3ErW%2FUh8f0%40I%3AZ%7C9eFSlMh4E%7EBi1b5IQ7cd6a%7EGoBj5.rIV',
       'types': ['Person'],
       'name': 'Michelle Obama',
       'diffbotUri': 'http://diffbot.com/entity/EUASG3qerM-KBugPoX67C6g',
       'targetDiffbotId': 'EUASG3qerM-KBugPoX67C6g',
       'type': 'Person'}},
     {'person': {'summary': 'Lawyer and former First Lady of the United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FfvEq%3ErW%2FUh8f0%40I%3AZ%7C9eFSlMh4E%7EBi1b5IQ7cd6a%7EGoBj5.rIV',
       'types': ['Person'],
       'name': 'Michelle Obama',
       'diffbotUri': 'http://diffbot.com/entity/EUASG3qerM-KBugPoX67C6g',
       'targetDiffbotId': 'EUASG3qerM-KBugPoX67C6g',
       'type': 'Person'},
      'from': {'str': 'd1992-10-03',
       'precision': 3,
       'timestamp': 718070400000},
      'type': 'Marriage'}],
    'languages': [{'str': 'English', 'normalizedValue': 'English'},
     {'str': 'Indonesian', 'normalizedValue': 'Indonesian'}],
    'wikipediaPageviewsLastQuarter': 2969229,
    'allUris': ['celebritynetworth.com/richest-politicians/presidents/barack-obama-net-worth',
     'bloomberg.com/profile/person/3296948',
     'classmates.com/people/barack-obama/8704402335',
     'classmates.com/people/Barack-Obama/8704402335',
     'classmates.com/people/Barack-Obama/8700666384',
     'classmates.com/people/Barack-Obama/8725018180',
     'classmates.com/people/Barack-Obama/8724207129',
     'classmates.com/people/barrack-obama/8725928770',
     'classmates.com/people/Barack-Obama/8704255405',
     'classmates.com/people/barack-obama/10100943046',
     'classmates.com/people/Barrack-Obama/8725928770',
     'classmates.com/people/barack-obama/8741335960',
     'classmates.com/people/barack-obama/8725018180',
     'classmates.com/people/barack-obama/8724207129',
     'classmates.com/people/barack-obama/8700666384',
     'classmates.com/people/barack-obama/8704255405',
     'crunchbase.com/person/barack-obama',
     'facebook.com/theoriginaljaybird',
     'facebook.com/pages/category/Public-Figure/POTUS44',
     'facebook.com/potus44',
     'facebook.com/POTUS44',
     'facebook.com/pages/category/Artist/theoriginaljaybird',
     'plus.google.com/107385984930630263523',
     'plus.google.com/112746106941558590272',
     'plus.google.com/103577439188064636391',
     'linkedin.com/in/barack-obama-8367661a8',
     'linkedin.com/in/barackobama',
     'theorg.com/org/obama-for-america/team/barack-obama',
     'wikidata.org/entity/Q76',
     'dbpedia.org/page/Barack_Obama',
     'en.wikipedia.org',
     'en.wikipedia.org/wiki/Barack_Obama',
     'wikidata.org/entity/Q117480686',
     'wikidata.org/entity/Q20086735',
     'wikidata.org/entity/Q21193',
     'wikidata.org/entity/Q55539',
     'wikidata.org/entity/Q808796',
     'dbpedia.org/resource/Barack_Obama',
     'facebook.com/barackobama',
     'twitter.com/BarackObama',
     'barackobama.com',
     'jaymitsch.com',
     'm.me/theoriginaljaybird',
     'whitehouse.gov',
     'm.me/POTUS44',
     'youtube.com/channel/UC54GVZO23_WV7XW9tM17ggQ',
     'reddit.com/user/PresidentObama',
     'g.co/kg/m/02mjmr',
     'medium.com/@BarackObama',
     'amazon.com/wd/e/B001H6OA8E',
     'youtube.com/channel/UCdn86UYrf54lXfVli9CB6Aw',
     'musicbrainz.org/artist/0de4d19f-05c8-4562-a3c0-7abdc144f1d5',
     'instagram.com/barackobama',
     'imdb.com/name/nm1682433',
     'd-nb.info/gnd/132522136',
     'viaf.org/viaf/52010985'],
    'employments': [{'isCurrent': True,
      'employer': {'summary': 'Chicago-based nonprofit organization founded in 2014',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FgvFt%3EtP%7DZd%7B%40%3AVh%3CZ3AuELrSl%3A.5Y%60',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Obama Foundation',
       'diffbotUri': 'http://diffbot.com/entity/ErwO36yiYP7-3rbnIp-PbZQ',
       'targetDiffbotId': 'ErwO36yiYP7-3rbnIp-PbZQ',
       'type': 'Organization'},
      'from': {'str': 'd2014-01-01',
       'precision': 3,
       'timestamp': 1388534400000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Founder',
        'diffbotUri': 'http://diffbot.com/entity/EoN4VH9EANdSbPUhVFBbVSQ',
        'targetDiffbotId': 'EoN4VH9EANdSbPUhVFBbVSQ',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'Founder'},
     {'isCurrent': True,
      'employer': {'name': 'Natl Basketball Assn', 'type': 'Organization'},
      'from': {'str': 'd2021-07-XX',
       'precision': 2,
       'timestamp': 1625097600000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Shareholder',
        'diffbotUri': 'http://diffbot.com/entity/EnjEbsIYNORq7LaLzpGLaeg',
        'targetDiffbotId': 'EnjEbsIYNORq7LaLzpGLaeg',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'Partner:Africa Strategic'},
     {'isCurrent': True,
      'employer': {'summary': 'Data collection and analysis provider',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3E%3FxPT%3AX%3E%3Ak%3AYr%7DbC%3DfEt5',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'HigherGround',
       'diffbotUri': 'http://diffbot.com/entity/ETLHsddrtO2mgIBBBz0o71g',
       'targetDiffbotId': 'ETLHsddrtO2mgIBBBz0o71g',
       'type': 'Organization'},
      'from': {'str': 'd2018-01-01',
       'precision': 3,
       'timestamp': 1514764800000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'Founder'},
     {'isCurrent': True,
      'employer': {'summary': 'Software company based in Madrid, Madrid Province, Spain',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EN%7D%60XwU70J8E%5CCVuIu%3Aaw',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'MotosierraTech',
       'diffbotUri': 'http://diffbot.com/entity/ESVgmzTtQOrOHSzSzBBB-Ow',
       'targetDiffbotId': 'ESVgmzTtQOrOHSzSzBBB-Ow',
       'type': 'Organization'},
      'from': {'str': 'd2019-01-01',
       'precision': 3,
       'timestamp': 1546300800000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Founder',
        'diffbotUri': 'http://diffbot.com/entity/EoN4VH9EANdSbPUhVFBbVSQ',
        'targetDiffbotId': 'EoN4VH9EANdSbPUhVFBbVSQ',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'Founder'},
     {'isCurrent': False,
      'employer': {'summary': 'U.S. federal government office of the president of the United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stn8p.%5DjEp9G.Bd%7Bk%3FVq%7Br5%7Bx-bxW%7D-Z5Zr-j6%7BE-b%7EswEYpTuiR%5DzN_%3Cb4E.A%5Dm',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'The White House',
       'diffbotUri': 'http://diffbot.com/entity/Ewvhj0aF6OY6BTNyslvJk6w',
       'targetDiffbotId': 'Ewvhj0aF6OY6BTNyslvJk6w',
       'type': 'Organization'},
      'from': {'str': 'd2009-01-01',
       'precision': 3,
       'timestamp': 1230768000000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Leadership',
        'diffbotUri': 'http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg',
        'targetDiffbotId': 'EVWkZnDeBNKaKUDZ_8WK0bg',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'President',
        'diffbotUri': 'http://diffbot.com/entity/EoOGiQBKyPo6fxgo68SaLSw',
        'targetDiffbotId': 'EoOGiQBKyPo6fxgo68SaLSw',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2017-01-20', 'precision': 3, 'timestamp': 1484870400000},
      'title': '44th President'},
     {'isCurrent': False,
      'employer': {'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A'},
      'from': {'str': 'd2009-01-20',
       'precision': 3,
       'timestamp': 1232409600000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Head of government',
        'diffbotUri': 'http://diffbot.com/entity/EG9NYFQwRNZKIOLTW5WwHcw',
        'targetDiffbotId': 'EG9NYFQwRNZKIOLTW5WwHcw',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2017-01-20', 'precision': 3, 'timestamp': 1484870400000},
      'title': 'President of the United States'},
     {'isCurrent': False,
      'employer': {'summary': 'American experimental rock and psychedelic band',
       'types': ['Organization'],
       'name': 'The United States of America',
       'diffbotUri': 'http://diffbot.com/entity/EFEvb9mMvOPC7CmkjxMTvUw',
       'targetDiffbotId': 'EFEvb9mMvOPC7CmkjxMTvUw',
       'type': 'Organization'},
      'from': {'str': 'd2009-01-XX',
       'precision': 2,
       'timestamp': 1230768000000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'President',
        'diffbotUri': 'http://diffbot.com/entity/EoOGiQBKyPo6fxgo68SaLSw',
        'targetDiffbotId': 'EoOGiQBKyPo6fxgo68SaLSw',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Leadership',
        'diffbotUri': 'http://diffbot.com/entity/EVWkZnDeBNKaKUDZ_8WK0bg',
        'targetDiffbotId': 'EVWkZnDeBNKaKUDZ_8WK0bg',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2017-01-XX', 'precision': 2, 'timestamp': 1483228800000},
      'title': 'President'},
     {'isCurrent': False,
      'employer': {'summary': 'Upper house of the United States Congress',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EJvPR%3Fi%3A%3DU1FrBR2Q%5D9q%7D',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Senate',
       'diffbotUri': 'http://diffbot.com/entity/EDXOHrBYDNaaAmnqOgZT_qg',
       'targetDiffbotId': 'EDXOHrBYDNaaAmnqOgZT_qg',
       'type': 'Organization'},
      'from': {'str': 'd2005-01-01',
       'precision': 3,
       'timestamp': 1104537600000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2008-11-01', 'precision': 3, 'timestamp': 1225497600000},
      'title': 'Senator:Illinois'},
     {'isCurrent': False,
      'employer': {'summary': 'Legislative branch of the state government of Illinois',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtp%3EnZ8Vq%3Bc%3E%40MLZ3%3DejNvMy%3APq%280CvHWuNp%3EW%29.MlA',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Illinois General Assembly',
       'diffbotUri': 'http://diffbot.com/entity/Exqb8kkXhNLKlvcqXDcquOg',
       'targetDiffbotId': 'Exqb8kkXhNLKlvcqXDcquOg',
       'type': 'Organization'},
      'from': {'str': 'd1996-01-XX',
       'precision': 2,
       'timestamp': 820454400000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2005-12-XX', 'precision': 2, 'timestamp': 1133395200000},
      'title': 'State Senator'},
     {'isCurrent': False,
      'employer': {'summary': 'Upper house of the United States Congress',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EJvPR%3Fi%3A%3DU1FrBR2Q%5D9q%7D',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Senate',
       'diffbotUri': 'http://diffbot.com/entity/EDXOHrBYDNaaAmnqOgZT_qg',
       'targetDiffbotId': 'EDXOHrBYDNaaAmnqOgZT_qg',
       'type': 'Organization'},
      'from': {'str': 'd2003-01-XX',
       'precision': 2,
       'timestamp': 1041379200000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2005-01-XX', 'precision': 2, 'timestamp': 1104537600000},
      'title': 'Candidate:Democratic Party'},
     {'isCurrent': False,
      'employer': {'summary': 'Private university in Chicago, Illinois',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40s%3Ez%5C5ch%3Em4Us7hu7I%3FViEl%3AC9Rkv%5DrI%5B.b%7B5',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'University of Chicago',
       'diffbotUri': 'http://diffbot.com/entity/E6CDGIdI_N165RN-b94EV6Q',
       'targetDiffbotId': 'E6CDGIdI_N165RN-b94EV6Q',
       'type': 'Organization'},
      'from': {'str': 'd1993-01-01',
       'precision': 3,
       'timestamp': 725846400000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Legal and Regulatory Compliance',
        'diffbotUri': 'http://diffbot.com/entity/E5eqWL0IJM86Q_o6a4P-u7w',
        'targetDiffbotId': 'E5eqWL0IJM86Q_o6a4P-u7w',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Senior',
        'diffbotUri': 'http://diffbot.com/entity/E44tGGbuVPHGMYsYaVkh8kA',
        'targetDiffbotId': 'E44tGGbuVPHGMYsYaVkh8kA',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2004-01-01', 'precision': 3, 'timestamp': 1072915200000},
      'title': 'Senior Lecturer in Law'},
     {'isCurrent': False,
      'employer': {'summary': 'Financial services company based in Alexandria, Virginia',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3EL%3EPYh%5Du%3DI%7DNl%7CW9Lf%3AZ%7C',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'United States Senate Federal Credit Union',
       'diffbotUri': 'http://diffbot.com/entity/EYefz-65mPHqgfvw3hr4IVQ',
       'targetDiffbotId': 'EYefz-65mPHqgfvw3hr4IVQ',
       'type': 'Organization'},
      'from': {'str': 'd1997-XX-XX',
       'precision': 1,
       'timestamp': 852076800000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2004-XX-XX', 'precision': 1, 'timestamp': 1072915200000},
      'title': 'State Senator'},
     {'isCurrent': False,
      'employer': {'summary': 'Faith-based organization in Chicago',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Developing Communities Project',
       'diffbotUri': 'http://diffbot.com/entity/EBGGso_pzN8uqo7aJroZQ0Q',
       'targetDiffbotId': 'EBGGso_pzN8uqo7aJroZQ0Q',
       'type': 'Organization'},
      'from': {'str': 'd1985-XX-XX',
       'precision': 1,
       'timestamp': 473385600000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd1988-XX-XX', 'precision': 1, 'timestamp': 567993600000},
      'title': 'community organizer'},
     {'isCurrent': False,
      'employer': {'summary': 'Corporation',
       'types': ['Organization'],
       'name': 'Business International',
       'diffbotUri': 'http://diffbot.com/entity/EQ9bjxZ7nPDOSCNh7xIz_bg',
       'targetDiffbotId': 'EQ9bjxZ7nPDOSCNh7xIz_bg',
       'type': 'Organization'},
      'from': {'str': 'd1983-XX-XX',
       'precision': 1,
       'timestamp': 410227200000},
      'to': {'str': 'd1984-XX-XX', 'precision': 1, 'timestamp': 441763200000},
      'title': 'assistant manager'},
     {'employer': {'name': 'United States National Science & Technology Council',
       'type': 'Organization'},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Chairman',
        'diffbotUri': 'http://diffbot.com/entity/ELiQhNkW0MuSuM5HPer8gpQ',
        'targetDiffbotId': 'ELiQhNkW0MuSuM5HPer8gpQ',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Board Member',
        'diffbotUri': 'http://diffbot.com/entity/EnC5drWy1NVuOGQHd2ll0xw',
        'targetDiffbotId': 'EnC5drWy1NVuOGQHd2ll0xw',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'CHAIRMAN'},
     {'employer': {'name': 'Public Health and Welfare Committee',
       'type': 'Organization'},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Chairman',
        'diffbotUri': 'http://diffbot.com/entity/ELiQhNkW0MuSuM5HPer8gpQ',
        'targetDiffbotId': 'ELiQhNkW0MuSuM5HPer8gpQ',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Board Member',
        'diffbotUri': 'http://diffbot.com/entity/EnC5drWy1NVuOGQHd2ll0xw',
        'targetDiffbotId': 'EnC5drWy1NVuOGQHd2ll0xw',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'CHAIRMAN'},
     {'employer': {'summary': 'Charitable foundation based in Chicago, Illinois, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FbvAn%3Eo%5DEPh%7B%40%3AVh%3CZ3AuELrSl%3A.%7CS%60',
       'types': ['Organization',
        'Corporation',
        'Company',
        'OrganizationInvestor'],
       'name': 'Joyce Foundation',
       'diffbotUri': 'http://diffbot.com/entity/E3H1TxNqtNXa0-yx4SQVmkA',
       'targetDiffbotId': 'E3H1TxNqtNXa0-yx4SQVmkA',
       'type': 'Organization'},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Executive',
        'diffbotUri': 'http://diffbot.com/entity/EFHD6pfzYMtqdaaytNomkhA',
        'targetDiffbotId': 'EFHD6pfzYMtqdaaytNomkhA',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Board Member',
        'diffbotUri': 'http://diffbot.com/entity/EnC5drWy1NVuOGQHd2ll0xw',
        'targetDiffbotId': 'EnC5drWy1NVuOGQHd2ll0xw',
        'type': 'EmploymentCategory'},
       {'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Management',
        'diffbotUri': 'http://diffbot.com/entity/EpXGc9jmNPQW3wt-ny5SqCQ',
        'targetDiffbotId': 'EpXGc9jmNPQW3wt-ny5SqCQ',
        'type': 'EmploymentCategory'}],
      'title': 'BOARD MEMBER'},
     {'employer': {'summary': 'Nonprofit organization in Chicago, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttU.LYeDo.C%7DLtpX%7C5kLP5%7CxKa%5EV%5CB95%5BkiheODqg%5DHurUw%2FqeN_Ma2%3BZr%5C',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Woods Fund of Chicago',
       'diffbotUri': 'http://diffbot.com/entity/EIsysycLKNKywOvj_GdP3Rg',
       'targetDiffbotId': 'EIsysycLKNKywOvj_GdP3Rg',
       'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'summary': 'Non-profit organization for political campaigns',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0Stn8p.%5DjEp9G.Bd%7Bko5R%7Etb%2FY-dxW%5C-Ze%5CQ-kiQj-b%7CIsH%5CoMq%3C1%5BzN_%3Cb4E.A%5Dm',
       'types': ['Organization'],
       'name': 'Obama for America',
       'diffbotUri': 'http://diffbot.com/entity/EkSVdYl5ePm6xYmsfz3uFpQ',
       'targetDiffbotId': 'EkSVdYl5ePm6xYmsfz3uFpQ',
       'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'summary': 'Non-profit organization in the USA',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHw%3EhS%3Aah%3EY1Pl7GtAm%3FOuVm%3ASvBMwSyE_%3A%5ElG%5B9RcI.%7BJo',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Center for Neighborhood Technology',
       'diffbotUri': 'http://diffbot.com/entity/EY2ye3154P5G34ddm-K9Bsg',
       'targetDiffbotId': 'EY2ye3154P5G34ddm-K9Bsg',
       'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'name': 'Community Law Project', 'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'name': 'Chicago Annebery Challenge',
       'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'name': "Crain's Chicago Business 40 Under 40",
       'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'name': 'Cook County Bar Assn', 'type': 'Organization'},
      'title': 'MEMBER'},
     {'employer': {'name': "Lawyer's Committee for Civil Rights Under Law Leadership",
       'type': 'Organization'},
      'title': 'MEMBER'},
     {'isCurrent': False,
      'employer': {'summary': 'U.S.-based corporate law firm',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FjvIS%3ExW0YhEY%5CVmLb%7D7rFTu.xAK',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'Sidley Austin',
       'diffbotUri': 'http://diffbot.com/entity/E-GdYBE4LPf-cYucqrZ4TRg',
       'targetDiffbotId': 'E-GdYBE4LPf-cYucqrZ4TRg',
       'type': 'Organization'},
      'from': {'str': 'd1991-XX-XX',
       'precision': 1,
       'timestamp': 662688000000},
      'to': {'str': 'd1991-XX-XX', 'precision': 1, 'timestamp': 662688000000}},
     {'isCurrent': False,
      'employer': {'summary': 'American political organization',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0SttAc%3ANu.d9U%7CB%5DpM08.%7DZnIa6%40_%3Bv2FpDLhawxEr-%5BuTpJZ%40-r%3Ec2Jh9e%3ER0P_xG%3C8jJ%5D%5C%7Eb%3AOs5dv',
       'types': ['Organization', 'Corporation', 'Company'],
       'name': 'NYPIRG',
       'diffbotUri': 'http://diffbot.com/entity/ERY0Ma-KoM7uXMXoqXifDWA',
       'targetDiffbotId': 'ERY0Ma-KoM7uXMXoqXifDWA',
       'type': 'Organization'},
      'from': {'str': 'd1985-XX-XX',
       'precision': 1,
       'timestamp': 473385600000},
      'to': {'str': 'd1985-XX-XX', 'precision': 1, 'timestamp': 473385600000}},
     {'isCurrent': True,
      'from': {'str': 'd1995-XX-XX',
       'precision': 1,
       'timestamp': 788918400000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'title': 'political writer'},
     {'isCurrent': True,
      'from': {'str': 'd1991-XX-XX',
       'precision': 1,
       'timestamp': 662688000000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Legal and Regulatory Compliance',
        'diffbotUri': 'http://diffbot.com/entity/E5eqWL0IJM86Q_o6a4P-u7w',
        'targetDiffbotId': 'E5eqWL0IJM86Q_o6a4P-u7w',
        'type': 'EmploymentCategory'}],
      'title': 'lawyer'},
     {'isCurrent': False,
      'from': {'str': 'd2007-01-03',
       'precision': 3,
       'timestamp': 1167782400000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Legal and Regulatory Compliance',
        'diffbotUri': 'http://diffbot.com/entity/E5eqWL0IJM86Q_o6a4P-u7w',
        'targetDiffbotId': 'E5eqWL0IJM86Q_o6a4P-u7w',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2008-11-16', 'precision': 3, 'timestamp': 1226793600000},
      'title': 'United States senator'},
     {'isCurrent': False,
      'from': {'str': 'd2005-01-03',
       'precision': 3,
       'timestamp': 1104710400000},
      'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Legal and Regulatory Compliance',
        'diffbotUri': 'http://diffbot.com/entity/E5eqWL0IJM86Q_o6a4P-u7w',
        'targetDiffbotId': 'E5eqWL0IJM86Q_o6a4P-u7w',
        'type': 'EmploymentCategory'}],
      'to': {'str': 'd2007-01-03', 'precision': 3, 'timestamp': 1167782400000},
      'title': 'United States senator'},
     {'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Politics',
        'diffbotUri': 'http://diffbot.com/entity/E1RVCb9E4Pmm4Ef66nDYygQ',
        'targetDiffbotId': 'E1RVCb9E4Pmm4Ef66nDYygQ',
        'type': 'EmploymentCategory'}],
      'title': 'politician'},
     {'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'News, Entertainment, Sports and Performing Arts',
        'diffbotUri': 'http://diffbot.com/entity/EZiGDC8yfMfSOEU2CfnbvMQ',
        'targetDiffbotId': 'EZiGDC8yfMfSOEU2CfnbvMQ',
        'type': 'EmploymentCategory'}],
      'title': 'memoirist'},
     {'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'News, Entertainment, Sports and Performing Arts',
        'diffbotUri': 'http://diffbot.com/entity/EZiGDC8yfMfSOEU2CfnbvMQ',
        'targetDiffbotId': 'EZiGDC8yfMfSOEU2CfnbvMQ',
        'type': 'EmploymentCategory'}],
      'title': 'podcaster'},
     {'categories': [{'types': ['Intangible', 'EmploymentCategory'],
        'name': 'Teaching and Academics',
        'diffbotUri': 'http://diffbot.com/entity/EaV9Qa49EO3G-Jg-1YDVURA',
        'targetDiffbotId': 'EaV9Qa49EO3G-Jg-1YDVURA',
        'type': 'EmploymentCategory'}],
      'title': 'academic'},
     {'title': 'jurist'},
     {'title': 'statesperson'}],
    'birthDate': {'str': 'd1961-08-04',
     'precision': 3,
     'timestamp': -265420800000},
    'religion': {'str': 'United Church of Christ'},
    'awards': [{'date': {'str': 'd2009-XX-XX',
       'precision': 1,
       'timestamp': 1230768000000},
      'title': 'King Abdulaziz Medal'},
     {'date': {'str': 'd2006-02-08',
       'precision': 3,
       'timestamp': 1139356800000},
      'title': 'Grammy Award for Best Audio Book, Narration & Storytelling Recording'},
     {'date': {'str': 'd2008-XX-XX',
       'precision': 1,
       'timestamp': 1199145600000},
      'title': 'Financial Times Person of the Year'},
     {'title': 'honorary doctor of the Northwestern University'},
     {'date': {'str': 'd2016-XX-XX',
       'precision': 1,
       'timestamp': 1451606400000},
      'title': 'German Media Award'},
     {'date': {'str': 'd2014-04-28',
       'precision': 3,
       'timestamp': 1398643200000},
      'title': 'Order of Sikatuna'},
     {'date': {'str': 'd2005-XX-XX',
       'precision': 1,
       'timestamp': 1104537600000},
      'title': "NAACP Image Award – Chairman's Award"},
     {'title': 'Order of the Rajamitrabhorn'},
     {'date': {'str': 'd2022-XX-XX',
       'precision': 1,
       'timestamp': 1640995200000},
      'title': 'Audie Award for Narration by the Author'},
     {'title': 'Romy'},
     {'title': 'National Medal of Science'},
     {'date': {'str': 'd2009-XX-XX',
       'precision': 1,
       'timestamp': 1230768000000},
      'title': 'Nobel Peace Prize'},
     {'title': 'Knight Commander of the Order of the British Empire'},
     {'date': {'str': 'd2013-03-21',
       'precision': 3,
       'timestamp': 1363824000000},
      'title': 'Presidential Medal of Distinction'},
     {'title': 'honorary doctorate from the University of Notre Dame'},
     {'date': {'str': 'd2008-XX-XX',
       'precision': 1,
       'timestamp': 1199145600000},
      'title': 'Phoenix Award'},
     {'date': {'str': 'd2008-XX-XX',
       'precision': 1,
       'timestamp': 1199145600000},
      'title': 'Time Person of the Year'},
     {'date': {'str': 'd2022-09-03',
       'precision': 3,
       'timestamp': 1662163200000},
      'title': 'Primetime Emmy Award for Outstanding Narrator'},
     {'title': 'honorary doctor of the University of Johannesburg'},
     {'date': {'str': 'd2007-XX-XX',
       'precision': 1,
       'timestamp': 1167609600000},
      'title': 'NAACP Image Award for Outstanding Literary Work, Nonfiction'},
     {'date': {'str': 'd2017-XX-XX',
       'precision': 1,
       'timestamp': 1483228800000},
      'title': 'Profile in Courage Award'}],
    'crunchbaseUri': 'crunchbase.com/person/barack-obama',
    'googlePlusUri': 'plus.google.com/107385984930630263523',
    'netWorth': {'currency': 'USD', 'value': 70000000.0},
    'allDescriptions': ['Barack Hussein Obama II (born August 4, 1961) is an American politician who served as the 44th president of the United States from 2009 to 2017. A member of the Democratic Party, he was the first in U.S. history. Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, as an Illinois state senator from 1997 to 2004, and as a community service organizer, civil rights lawyer, and university lecturer.',
     'Barack Obama is the Founder of Higher Ground. He previously worked at the Illinois State Senate as a State Senator. Barack Obama attended Harvard University.',
     'Before entering politics, Obama graduated from Harvard Law School, where he served as the first African American president of the Harvard Law Review. After graduating, he worked as a civil rights attorney and taught constitutional law at the University of Chicago Law School.',
     'Works at The White House. Lives in United States. Lived in White House, TN, United States, North America.'],
    'locations': [{'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': True,
      'address': 'Washington, D.C., District of Columbia',
      'city': {'summary': 'Capital city of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Washington, D.C.',
       'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
       'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
       'type': 'Place'},
      'metroArea': {'summary': 'Metropolitan area centered on Washington, D.C.',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvup%3EiQNof%3Bo9Uc%3Dl.Bv%3E',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Washington metropolitan area',
       'diffbotUri': 'http://diffbot.com/entity/EbKIavbI8PhiHKmthsK_vTw',
       'targetDiffbotId': 'EbKIavbI8PhiHKmthsK_vTw',
       'type': 'Place'},
      'subregion': {'summary': 'Capital city of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Washington, D.C.',
       'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
       'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
       'type': 'Place'},
      'latitude': 38.82651901245117,
      'precision': 13.315855979919434,
      'postalCode': '20032',
      'surfaceForm': 'Washington, D.C., District of Columbia',
      'region': {'summary': 'Capital city of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Washington, D.C.',
       'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
       'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
       'type': 'Place'},
      'longitude': -77.01712036132812},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'address': 'Chicago, Illinois',
      'city': {'summary': 'City and county seat of Cook County, Illinois, United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvts%3EzA-6O-%3D3J%5D9%60%7E.vET',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Chicago',
       'diffbotUri': 'http://diffbot.com/entity/Efsd1HzRPP02EPZJnOZPfQA',
       'targetDiffbotId': 'Efsd1HzRPP02EPZJnOZPfQA',
       'type': 'Place'},
      'metroArea': {'summary': 'Metropolitan area in the United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqo%3EhV5Pd3izB_JbpDeMVk%5B.5Ty',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Chicago metropolitan area',
       'diffbotUri': 'http://diffbot.com/entity/EDdaNkfPANReoJCWjJ4clcQ',
       'targetDiffbotId': 'EDdaNkfPANReoJCWjJ4clcQ',
       'type': 'Place'},
      'subregion': {'summary': 'County in Illinois, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FdvCq%3EkZ%7DTb%3B%60ztiGdnkuL%5Bz%5D%2Cz%7D%7EOb0_zJ.Ael',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Cook County',
       'diffbotUri': 'http://diffbot.com/entity/EwHZrCbVWNDicxOVF-SN4eQ',
       'targetDiffbotId': 'EwHZrCbVWNDicxOVF-SN4eQ',
       'type': 'Place'},
      'latitude': 41.878971099853516,
      'precision': 24.438631057739258,
      'postalCode': '60607',
      'surfaceForm': 'Chicago, Illinois',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHp%3EnZ8Vq%3Bc%3E%40%3D9g8Gt6-eTf9S4Df%7B_.A%605',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'Illinois',
       'diffbotUri': 'http://diffbot.com/entity/EbCHmKRdnPNWDRqTZHroFbA',
       'targetDiffbotId': 'EbCHmKRdnPNWDRqTZHroFbA',
       'type': 'Place'},
      'longitude': -87.66062927246094},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'address': 'Houston, Texas, United States',
      'city': {'summary': 'City in Harris, Fort Bend, and Montgomery counties in Texas, United States, and the county seat of Harris County',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDq%3EmO%3E_l%3FY%5EPoFm87NFbyXt9.5Y%60',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Houston',
       'diffbotUri': 'http://diffbot.com/entity/EvETmIj-lOaehBN1yx3Vy0A',
       'targetDiffbotId': 'EvETmIj-lOaehBN1yx3Vy0A',
       'type': 'Place'},
      'metroArea': {'summary': 'Metropolitan area in Texas, USA',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDr%3EuO%3A%5Cu%7Dg4DYph4KzF%5BeWpDP%7BQ%5E.Z1%3E',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Greater Houston',
       'diffbotUri': 'http://diffbot.com/entity/ElxXJ4OFfOn2Pt_7jZxn47g',
       'targetDiffbotId': 'ElxXJ4OFfOn2Pt_7jZxn47g',
       'type': 'Place'},
      'subregion': {'summary': 'County in Texas, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtv%3ExS%7DYb%3B%60zy%5BJkxKej%5C%7BRyD%2Cq7%5E%3AQ4.cDV',
       'types': ['Place', 'AdministrativeArea', 'Subregion'],
       'name': 'Harris County',
       'diffbotUri': 'http://diffbot.com/entity/E4xjIWnOaP3qDrKVOowXw-g',
       'targetDiffbotId': 'E4xjIWnOaP3qDrKVOowXw-g',
       'type': 'Place'},
      'latitude': 29.784753799438477,
      'precision': 40.336021423339844,
      'postalCode': '77009',
      'surfaceForm': 'Houston, Texas, United States',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FgvFv%3Er%5DA%5Bw%7B%3C%3AOh%3De%7B78Wm%3E.o%3BK',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'Texas',
       'diffbotUri': 'http://diffbot.com/entity/EkoIuXpjvM6eoD4DCh1PbPA',
       'targetDiffbotId': 'EkoIuXpjvM6eoD4DCh1PbPA',
       'type': 'Place'},
      'longitude': -95.36141967773438},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'address': 'United States',
      'latitude': 39.71614074707031,
      'precision': 3133.163818359375,
      'surfaceForm': 'United States',
      'longitude': -96.9992446899414},
     {'address': 'The White House'},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'New York City, New York',
      'city': {'summary': 'Most populous city in the United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FgvFT%3Ef%609%60b%3B%60z%2F_OXhGxBLIMyD.5Y%60',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'New York City',
       'diffbotUri': 'http://diffbot.com/entity/EcMmgf99wMQ6XYnbChv5HiQ',
       'targetDiffbotId': 'EcMmgf99wMQ6XYnbChv5HiQ',
       'type': 'Place'},
      'metroArea': {'summary': 'Most populous metropolitan area in the United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGp%3EsG%7B%3Ah%40l%3AQiDb39t6%7ExIf.T0J',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'New York metropolitan area',
       'diffbotUri': 'http://diffbot.com/entity/EAtK9ZhUYMKmI_UzSrYinmw',
       'targetDiffbotId': 'EAtK9ZhUYMKmI_UzSrYinmw',
       'type': 'Place'},
      'subregion': {'summary': 'County in New York, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvun%3Es%5D%3Eak%7BQ4MfAZ%7CKhL_m%2CdbVwHg2_zEd%2CNf%3C%60%7C%2FkHbps%7BEPvJf%60O8%5EZ7%5D%3CE%5B%3EVz%2F_BDqAb1%3BpM%60wGkDQ2Kf4%5Bt%3Ch1w%3BV_cLdDn7BkniqX06%2Cw%40h4b0%3EcGW0Fi%2CHDRp6KzXcm-lUlLk1SxO.bF%5E',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Kings County',
       'diffbotUri': 'http://diffbot.com/entity/EKWYc_xx-NaabzSSg9oK5tw',
       'targetDiffbotId': 'EKWYc_xx-NaabzSSg9oK5tw',
       'type': 'Place'},
      'latitude': 40.68294906616211,
      'precision': 27.98809051513672,
      'postalCode': '11217',
      'surfaceForm': 'New York City, New York',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FevDp%3EsGo0d%3Cc%3FPfxZ%7DGx8Zg.o%3BK',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'New York',
       'diffbotUri': 'http://diffbot.com/entity/E1NxI_KXaMbiP5g2aM9MRdw',
       'targetDiffbotId': 'E1NxI_KXaMbiP5g2aM9MRdw',
       'type': 'Place'},
      'longitude': -73.9708023071289},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'Honolulu, Hawaii',
      'city': {'summary': 'City in and county seat of Honolulu County, Hawaii, United States, that is also the capital city of Hawaii',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FcvBv%3Em%5D%3A%5CoAf%40%40%3DGn%7DL%2F65g%5Bf4Mq%7Cgu_3G_%40Py3%60%7CDj%3EZfHqGRwXw%3CXuY%60xQtKW1dfhm%3DTjQi8%3BRDXrTr6P%3ALa.g%3BB',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Honolulu',
       'diffbotUri': 'http://diffbot.com/entity/EmWlgdI4VNVSuyG-mKiFL_Q',
       'targetDiffbotId': 'EmWlgdI4VNVSuyG-mKiFL_Q',
       'type': 'Place'},
      'subregion': {'summary': 'County in Hawaii, United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FdvCw%3Em%5D%3A%5CoAf%40a%7B.C_o',
       'types': ['Place', 'AdministrativeArea', 'Subregion'],
       'name': 'Honolulu County',
       'diffbotUri': 'http://diffbot.com/entity/E1A5FurgPOxy29DkMacMLrQ',
       'targetDiffbotId': 'E1A5FurgPOxy29DkMacMLrQ',
       'type': 'Place'},
      'latitude': 19.647634506225586,
      'precision': 168.5026092529297,
      'postalCode': '96750',
      'surfaceForm': 'Honolulu, Hawaii',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FDvsO%3ExS%7DYb%3B%60zUb%3DXbLgKReSkz%7CsZZ%7BY.Jf5',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'Hawaii',
       'diffbotUri': 'http://diffbot.com/entity/E8C57xBfCOsyYwfJ2yuuJEA',
       'targetDiffbotId': 'E8C57xBfCOsyYwfJ2yuuJEA',
       'type': 'Place'},
      'longitude': -155.5332489013672},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'Los Angeles, California',
      'city': {'summary': 'Largest city in California, United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHs%3EkZ%7DTb%3B%60z%7DiKXPFm%3CYkW%2CzwsObx_3EY%2F.xDc',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Los Angeles',
       'diffbotUri': 'http://diffbot.com/entity/E6bKNJcg1NSCcebJ9lwR4Pw',
       'targetDiffbotId': 'E6bKNJcg1NSCcebJ9lwR4Pw',
       'type': 'Place'},
      'metroArea': {'summary': 'Metropolitan area in California, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtu%3Eq%5D%3FLD%3Aa0M_K%2CnkG6SxSrzXzHXsY3.Z%3EV',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Los Angeles metropolitan area',
       'diffbotUri': 'http://diffbot.com/entity/EKhZFGU1RPQi0GJOv2ZIylw',
       'targetDiffbotId': 'EKhZFGU1RPQi0GJOv2ZIylw',
       'type': 'Place'},
      'subregion': {'summary': 'County in California, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtu%3Eq%5D%3FLD%3Aa0M_K%2CnkG6SxSrzXzHXsY3.Z%3EV',
       'types': ['Place', 'AdministrativeArea', 'Subregion'],
       'name': 'Los Angeles County',
       'diffbotUri': 'http://diffbot.com/entity/ELvekhrK-MZSKBlAHI-t_Pg',
       'targetDiffbotId': 'ELvekhrK-MZSKBlAHI-t_Pg',
       'type': 'Place'},
      'latitude': 34.05513000488281,
      'precision': 35.194480895996094,
      'postalCode': '90071',
      'surfaceForm': 'Los Angeles, California',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtr%3EnAo-8UY%5EBfA_%7EJt%40N%2CCS0ZsGZqQ%2F%3BO%3C%5EwBd2Uj9HvRq%3C%5E.Pw4',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'California',
       'diffbotUri': 'http://diffbot.com/entity/El0_8ehooNxOPT36Y4RdV9w',
       'targetDiffbotId': 'El0_8ehooNxOPT36Y4RdV9w',
       'type': 'Place'},
      'longitude': -118.25702667236328},
     {'country': {'summary': 'Country in Southeast Asia and Oceania',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40s%3En%5C0%5Cq1m4BY%28h1LnFTxEu3MuBi4_%7B%3CSBXt%3C%29.VrA',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'Indonesia',
       'diffbotUri': 'http://diffbot.com/entity/EZWmXXYZUOlKaiPpHF911Jg',
       'targetDiffbotId': 'EZWmXXYZUOlKaiPpHF911Jg',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'Tebet, Jakarta, Indonesia',
      'city': {'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Jakarta',
       'diffbotUri': 'http://diffbot.com/entity/EuNEkEq7COheK-q0LtNyONw',
       'targetDiffbotId': 'EuNEkEq7COheK-q0LtNyONw',
       'type': 'Place'},
      'subregion': {'types': ['Place', 'AdministrativeArea', 'Subregion'],
       'name': 'Jakarta Pusat Municipality',
       'diffbotUri': 'http://diffbot.com/entity/E2PJoN55sOrmK_F43rt6YYQ',
       'targetDiffbotId': 'E2PJoN55sOrmK_F43rt6YYQ',
       'type': 'Place'},
      'latitude': -6.1822829246521,
      'precision': 6.942142963409424,
      'surfaceForm': 'Tebet, Jakarta, Indonesia',
      'region': {'summary': 'Capital city and smallest province of Indonesia',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FbvAQ%3EoO7Nu%40%5BzWo%3DX%2F9x6%60gXj7P%7BW%5EqU%2F6rNq7.f%3DJ',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Jakarta',
       'diffbotUri': 'http://diffbot.com/entity/EvNjeY5iAPMOz3G_LtmGtYQ',
       'targetDiffbotId': 'EvNjeY5iAPMOz3G_LtmGtYQ',
       'type': 'Place'},
      'longitude': 106.83942413330078},
     {'venue': 'Área Metropolitana De Washington',
      'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'Área Metropolitana de Washington D.C., Estados Unidos',
      'metroArea': {'summary': 'Metropolitan area centered on Washington, D.C.',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvup%3EiQNof%3Bo9Uc%3Dl.Bv%3E',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Washington metropolitan area',
       'diffbotUri': 'http://diffbot.com/entity/EbKIavbI8PhiHKmthsK_vTw',
       'targetDiffbotId': 'EbKIavbI8PhiHKmthsK_vTw',
       'type': 'Place'},
      'latitude': 38.9120979309082,
      'precision': 13.299211502075195,
      'surfaceForm': 'Área Metropolitana de Washington D.C., Estados Unidos',
      'region': {'summary': 'Capital city of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Washington, D.C.',
       'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
       'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
       'type': 'Place'},
      'longitude': -77.01468658447266},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'Washington D.C. Metro Area',
      'metroArea': {'summary': 'Metropolitan area centered on Washington, D.C.',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvup%3EiQNof%3Bo9Uc%3Dl.Bv%3E',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Washington metropolitan area',
       'diffbotUri': 'http://diffbot.com/entity/EbKIavbI8PhiHKmthsK_vTw',
       'targetDiffbotId': 'EbKIavbI8PhiHKmthsK_vTw',
       'type': 'Place'},
      'subregion': {'summary': 'Capital city of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Washington, D.C.',
       'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
       'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
       'type': 'Place'},
      'latitude': 38.82651901245117,
      'precision': 20,
      'surfaceForm': 'Washington D.C. Metro Area',
      'region': {'summary': 'Capital city of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Washington, D.C.',
       'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
       'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
       'type': 'Place'},
      'longitude': -77.01712036132812},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'isCurrent': False,
      'address': 'Houston, Texas Area',
      'latitude': 31.030973434448242,
      'precision': 500,
      'surfaceForm': 'Houston, Texas Area',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FgvFv%3Er%5DA%5Bw%7B%3C%3AOh%3De%7B78Wm%3E.o%3BK',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'Texas',
       'diffbotUri': 'http://diffbot.com/entity/EkoIuXpjvM6eoD4DCh1PbPA',
       'targetDiffbotId': 'EkoIuXpjvM6eoD4DCh1PbPA',
       'type': 'Place'},
      'longitude': -98.32633209228516},
     {'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'address': 'Harvard, MA',
      'city': {'summary': 'Town in Worcester County, Massachusetts, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvus%3EmO%3Ecd%3E%5Ez5iOgnpgCY%2CCM%7CV8DkvO%5Eh.8_l',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'Harvard',
       'diffbotUri': 'http://diffbot.com/entity/Ej3rB7K8qN-6aw-eO2ubxhQ',
       'targetDiffbotId': 'Ej3rB7K8qN-6aw-eO2ubxhQ',
       'type': 'Place'},
      'metroArea': {'summary': 'Metropolitan area in Massachusetts, New Hampshire and Rhode Island, USA',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FEvtp%3El%601Nw1l%7DPmLh%7DZ.G%5Bm',
       'types': ['Place', 'AdministrativeArea'],
       'name': 'Greater Boston',
       'diffbotUri': 'http://diffbot.com/entity/Es5VXYfClMLeSpzD5N0Cx1A',
       'targetDiffbotId': 'Es5VXYfClMLeSpzD5N0Cx1A',
       'type': 'Place'},
      'subregion': {'summary': 'County in Massachusetts, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40o%3ErO%3CLr2YhBmKZr%40%7BJRzXxzL%7BJa%7EYx%3Fd7%5Dl%7DS%3CU_%3Fn5%3Fz82w%5BuA_.Xq%7B',
       'types': ['Place', 'AdministrativeArea', 'Subregion'],
       'name': 'Worcester County',
       'diffbotUri': 'http://diffbot.com/entity/E8u8vfcabMT6H3k7sglXmXw',
       'targetDiffbotId': 'E8u8vfcabMT6H3k7sglXmXw',
       'type': 'Place'},
      'latitude': 42.3587532043457,
      'precision': 165.21200561523438,
      'postalCode': '01752',
      'surfaceForm': 'Harvard, MA',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FivHp%3ExS%7DYb%3B%60z%7E%5BKlp%3BnL%60kXy%3E.5Y%60',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'Massachusetts',
       'diffbotUri': 'http://diffbot.com/entity/E0VAbhEeRNsSvhHIpmhd3Xw',
       'targetDiffbotId': 'E0VAbhEeRNsSvhHIpmhd3Xw',
       'type': 'Place'},
      'longitude': -71.53148651123047},
     {'venue': 'States North America',
      'country': {'summary': 'Country primarily located in North America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
       'types': ['Place', 'AdministrativeArea', 'Country'],
       'name': 'United States of America',
       'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
       'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
       'type': 'Place'},
      'address': 'White House, TN, United States, North America',
      'city': {'summary': 'City in Tennessee, United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FBvqo%3E%7C6q1bpiBFl7z.Bv%3E',
       'types': ['Place', 'AdministrativeArea', 'City'],
       'name': 'White House',
       'diffbotUri': 'http://diffbot.com/entity/E1OAa6CUeNm2kAstQhO6UKA',
       'targetDiffbotId': 'E1OAa6CUeNm2kAstQhO6UKA',
       'type': 'Place'},
      'subregion': {'summary': 'County in Tennessee, United States',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FbvAt%3ErO%3CLr2YoFhF%5E2Kk%3CLnMl3P%7BJa6Y%2F%3EOp%5Eg3nAVkHZTI%7DGc1.zCM',
       'types': ['Place', 'AdministrativeArea', 'Subregion'],
       'name': 'Robertson County',
       'diffbotUri': 'http://diffbot.com/entity/EYOvK8mKpNkWW3D6FiTfQpA',
       'targetDiffbotId': 'EYOvK8mKpNkWW3D6FiTfQpA',
       'type': 'Place'},
      'latitude': 36.467613220214844,
      'precision': 5.3694915771484375,
      'postalCode': '37188',
      'surfaceForm': 'White House, TN, United States, North America',
      'region': {'summary': 'State of the United States of America',
       'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FDvsq%3EqO7Rbhc9Em%3DrnAt61gZn%2FCUUhu%5BvKd%7DBy%2Fp2BL%3Bm%7C9%28sdvKfOfDj%29.%5C3%40',
       'types': ['Place', 'AdministrativeArea', 'Region'],
       'name': 'Tennessee',
       'diffbotUri': 'http://diffbot.com/entity/ECt3AOVpaOGCPcVORLFAJ6g',
       'targetDiffbotId': 'ECt3AOVpaOGCPcVORLFAJ6g',
       'type': 'Place'},
      'longitude': -86.6685562133789}],
    'location': {'country': {'summary': 'Country primarily located in North America',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FhvGq%3Eh%5D%7Dab%3B%60zBlElnGl6anIdpR%7BW%5EvOdKQBTx.oCJ',
      'types': ['Place', 'AdministrativeArea', 'Country'],
      'name': 'United States of America',
      'diffbotUri': 'http://diffbot.com/entity/E01d4EK33MmCosgI2KXa4-A',
      'targetDiffbotId': 'E01d4EK33MmCosgI2KXa4-A',
      'type': 'Place'},
     'isCurrent': True,
     'address': 'Washington, D.C., District of Columbia',
     'city': {'summary': 'Capital city of the United States of America',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
      'types': ['Place', 'AdministrativeArea', 'City'],
      'name': 'Washington, D.C.',
      'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
      'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
      'type': 'Place'},
     'metroArea': {'summary': 'Metropolitan area centered on Washington, D.C.',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvup%3EiQNof%3Bo9Uc%3Dl.Bv%3E',
      'types': ['Place', 'AdministrativeArea'],
      'name': 'Washington metropolitan area',
      'diffbotUri': 'http://diffbot.com/entity/EbKIavbI8PhiHKmthsK_vTw',
      'targetDiffbotId': 'EbKIavbI8PhiHKmthsK_vTw',
      'type': 'Place'},
     'subregion': {'summary': 'Capital city of the United States of America',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
      'types': ['Place', 'AdministrativeArea', 'City'],
      'name': 'Washington, D.C.',
      'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
      'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
      'type': 'Place'},
     'latitude': 38.82651901245117,
     'precision': 13.315855979919434,
     'postalCode': '20032',
     'surfaceForm': 'Washington, D.C., District of Columbia',
     'region': {'summary': 'Capital city of the United States of America',
      'image': 'https://kg.diffbot.com/image/api/get?fetch=yes&url=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3Fav%40q%3EkZ%7DTb%3B%60z8%5BKaxFmK%5Ct%2Cd_.U.l8W',
      'types': ['Place', 'AdministrativeArea', 'City'],
      'name': 'Washington, D.C.',
      'diffbotUri': 'http://diffbot.com/entity/Ep2MLLdkjO_C-R6NA7cOlcQ',
      'targetDiffbotId': 'Ep2MLLdkjO_C-R6NA7cOlcQ',
      'type': 'Place'},
     'longitude': -77.01712036132812},
    'wikipediaPageviewsGrowth': -0.10315922,
    'instagramUri': 'instagram.com/barackobama',
    'age': 62},
   'errors': []}],
 'errors': []}

# %%
import logging
import os
from datetime import datetime
from typing import Any, Dict, List, Optional, Union
from urllib.parse import urlencode

import requests

def get_people_params(row: Dict) -> Optional[Dict]:
    firstName = row.get("nameDetail", {}).get("firstName", "")
    lastName = row.get("nameDetail", {}).get("lastName", "")
    name = (firstName + " " + lastName).strip()
    
    # Skip entries without a valid name
    if not name:
        return None

    node_properties = {
        "education": row.get("educations", [{}])[0].get("institution", {}).get("name", ""),
        "wikipedia": row.get("wikipediaUri", {}),
        "description": row.get("description", {}),
        "summary": row.get("summary", {}),
        "net_worth": (str(row.get("netWorth", {}).get('value', '')) + " " + row.get("netWorth", {}).get('currency', '')).strip(),
        "birth_date": row.get("birthDate", {}).get("str", "")[1:],
        "linkedin": row.get("linkedInUri", {}),
    }

    locations = [
        {"city": el.get("city", {}).get("name", ""), "summary": el.get("city", {}).get("summary", ""), "country": el.get("country", {}).get("name", "")}
        for el in row.get("locations", []) if el.get("city", {}).get("name", "")
    ]

    nationalities = [{
        "name": row["nationalities"][-1]["name"],
        "type": row["nationalities"][-1].get("type", "Nationality")
    }] if row.get("nationalities") and "name" in row["nationalities"][-1] else []


    employments = [
        {
            "title": el.get("title"),
            "employer": el.get("employer", {}).get("name"),
            "isCurrent": el.get("isCurrent", False),
            "from": el.get("from", {}).get("str", "")[1:5],
            "to": el.get("to", {}).get("str", "")[1:5],
        }
        for el in row.get("employments", [])
        if el.get("title") and el.get("employer", {}).get("name")
    ]

    return {
        "name": name,
        "type": row["type"],
        "node_properties": node_properties,
        "locations": locations,
        "nationalities": nationalities,
        "employments": employments
    }

# %%
def store_enhanced_data(data: List[Dict[str, Any]]) -> Dict:
    organizations = []
    people = []
    no_data = []
    for name, element in data:
        try:
            entity = element["data"][0]["entity"]
        except (TypeError, IndexError):
            no_data.append(name)
            continue
        type = entity["type"]
        if type == "Organization":
            params = get_organization_params(name, entity)
            organizations.append(params)
        elif type == "Person":
            params = get_people_params(entity)
            people.append(params)
    # Save processes status to entities without any response
    if no_data:
        graph.query(no_data_processed_query, {"data": no_data})
    # Store organization
    if organizations:
        graph.query(organization_import_query, {"data": organizations})
    if people:
        graph.query(person_import_query, {"data": people})
    return {"organizations": len(organizations), "people": len(people)}

# %%
person_import_query = """
    UNWIND $data AS row
    MERGE (p:Person {name: row.name})
    SET p += row.node_properties
    WITH p, row
    
    CALL {
        WITH p, row
        UNWIND row.locations AS loc
        MERGE (city:City {name: loc.city})
        ON CREATE SET city.summary = loc.summary, city.country = loc.country
        MERGE (p)-[:PERSON_LOCATION]->(city)
        RETURN count(*) AS locationCount
    }
    
    CALL {
        WITH p, row
        UNWIND row.nationalities AS nat
        MERGE (n:Nationality {name: nat.name})
        ON CREATE SET n.type = nat.type
        MERGE (p)-[:HAS_NATIONALITY]->(n)
        RETURN count(*) AS nationalityCount
    }
    
    CALL {
        WITH p, row
        UNWIND row.employments AS emp
        MERGE (org:Organization {name: emp.employer})
        WITH p, org, emp
        CALL apoc.create.relationship(p, toUpper(emp.title), {isCurrent: emp.isCurrent, fromYear: emp.from, toYear: emp.to}, org) YIELD rel
        RETURN count(*) AS employmentCount
    }

    RETURN count(*) AS total
"""

# %%
print(get_people_params(data['data'][0]['entity']))
# Out:
# {'name': 'Barack Obama', 'type': 'Person', 'node_properties': {'education': 'University of Chicago', 'wikipedia': 'en.wikipedia.org/wiki/Barack_Obama', 'description': 'Barack Hussein Obama II (born August 4, 1961) is an American politician who served as the 44th president of the United States from 2009 to 2017. A member of the Democratic Party, he was the first in U.S. history. Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, as an Illinois state senator from 1997 to 2004, and as a community service organizer, civil rights lawyer, and university lecturer.', 'summary': 'President of the United States from 2009 to 2017', 'net_worth': '70000000.0 USD', 'birth_date': '1961-08-04', 'linkedin': 'linkedin.com/in/barackobama'}, 'locations': [{'city': 'Washington, D.C.', 'summary': 'Capital city of the United States of America', 'country': 'United States of America'}, {'city': 'Chicago', 'summary': 'City and county seat of Cook County, Illinois, United States
# ...
